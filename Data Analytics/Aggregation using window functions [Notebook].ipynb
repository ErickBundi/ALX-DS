# %% [markdown]
# <div align="right" style=" font-size: 80%; text-align: center; margin: 0 auto">
# <img
#  src="https://raw.githubusercontent.com/Explore-AI/Pictures/master/alx-courses/aice/assets/Content_page_banner_blue_dots.png"
#  alt="ALX Content Header"
#  class="full-width-image"
# />
# </div>

# %% [markdown]
# # Aggregation using window functions

# %% [markdown]
# > ⚠️ This notebook will not run on Google Colab because it cannot connect to a local database. Please make sure that this notebook is running on the same local machine as your MySQL Workbench installation and MySQL `united_nations` database.

# %% [markdown]
# ## Learning objectives
#
# - Understand the concept of window functions in SQL.
# - Learn how to use window functions for data aggregation.
# - Understand how to use window functions to partition data.
# - Practise using window functions to solve complex problems.

# %% [markdown]
# ## Overview
#
# In this notebook, we will explore how to use window functions in SQL to solve complex problems. Window functions are a type of function in SQL that performs a calculation across a set of table rows that are related to the current row.
#
# We will use the `united_nations.Access_to_Basic_Services` table, which contains information about different countries, their GDP, and access to basic services.
#
# Let's begin by calculating each country's land cover as a percentage per subregion for the year 2020.

# %% [markdown]
# ### Connecting to our MySQL database
#
# Since we have a MySQL database, we can connect to it using mysql and pymysql.

# %%
# Load and activate the SQL extension to allow us to execute SQL in a Jupyter notebook.

# %load_ext sql

# %%
# Establish a connection to the local database using the '%sql' magic command.
# Replace 'password' with our connection password and `db_name` with our database name.

# %sql mysql+pymysql://root:beardmayor13@localhost:3306/united_nations

# %% [markdown]
# ## Exercise
#
# ### Task 1: Select the data required for the analysis
#
# The columns you select should include:
# - `Sub_region`
# - `Country_name`
# - `Land_area`
#
# Filter out the results using the following criteria:
# - For the `Time_period` of `2020`.
# - For `Land_area` values that are not missing.

# %%
# %%sql
# -- Add your code here
# SELECT
#     Sub_region,
#     Country_name,
#     Land_area,
#     SUM(Land_area) OVER (
#         PARTITION BY Sub_region
#     ) AS Pct_Sub_region_land_area
# FROM
#     access_to_basic_services
# WHERE
#     Time_period = 2020
# AND
#     Land_area IS NOT NULL;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/united_nations
# 130 rows affected.
# [('Australia and New Zealand', 'Australia', Decimal('7692020.00'), Decimal('7955330.00')),
#  ('Australia and New Zealand', 'New Zealand', Decimal('263310.00'), Decimal('7955330.00')),
#  ('Caribbean', 'Jamaica', Decimal('10830.00'), Decimal('205080.00')),
#  ('Caribbean', 'Trinidad and Tobago', Decimal('5130.00'), Decimal('205080.00')),
#  ('Caribbean', 'Barbados', Decimal('430.00'), Decimal('205080.00')),
#  ('Caribbean', 'British Virgin Islands', Decimal('150.00'), Decimal('205080.00')),
#  ('Caribbean', 'Cuba', Decimal('103800.00'), Decimal('205080.00')),
#  ('Caribbean', 'Dominican Republic', Decimal('48310.00'), Decimal('205080.00')),
#  ('Caribbean', 'Haiti', Decimal('27560.00'), Decimal('205080.00')),
#  ('Caribbean', 'Puerto Rico', Decimal('8870.00'), Decimal('205080.00')),
#  ('Central America', 'Nicaragua', Decimal('120340.00'), Decimal('2452110.00')),
#  ('Central America', 'Mexico', Decimal('1943950.00'), Decimal('2452110.00')),
#  ('Central America', 'Honduras', Decimal('111890.00'), Decimal('2452110.00')),
#  ('Central America', 'Guatemala', Decimal('107160.00'), Decimal('2452110.00')),
#  ('Central America', 'El Salvador', Decimal('20720.00'), Decimal('2452110.00')),
#  ('Central America', 'Panama', Decimal('74180.00'), Decimal('2452110.00')),
#  ('Central America', 'Costa Rica', Decimal('51060.00'), Decimal('2452110.00')),
#  ('Central America', 'Belize', Decimal('22810.00'), Decimal('2452110.00')),
#  ('Central Asia', 'Tajikistan', Decimal('138790.00'), Decimal('3749070.00')),
#  ('Central Asia', 'Turkmenistan', Decimal('469930.00'), Decimal('3749070.00')),
#  ('Central Asia', 'Uzbekistan', Decimal('440650.00'), Decimal('3749070.00')),
#  ('Central Asia', 'Kazakhstan', Decimal('2699700.00'), Decimal('3749070.00')),
#  ('Eastern Africa', 'Mauritius', Decimal('2030.00'), Decimal('5825761.26')),
#  ('Eastern Africa', 'Malawi', Decimal('94280.00'), Decimal('5825761.26')),
#  ('Eastern Africa', 'Madagascar', Decimal('581800.00'), Decimal('5825761.26')),
#  ('Eastern Africa', 'Kenya', Decimal('569140.00'), Decimal('5825761.26')),
#  ('Eastern Africa', 'Djibouti', Decimal('23180.00'), Decimal('5825761.26')),
#  ('Eastern Africa', 'Burundi', Decimal('25680.00'), Decimal('5825761.26')),
#  ('Eastern Africa', 'Uganda', Decimal('200520.00'), Decimal('5825761.26')),
#  ('Eastern Africa', 'Mozambique', Decimal('786380.00'), Decimal('5825761.26')),
#  ('Eastern Africa', 'Ethiopia', Decimal('1128571.26'), Decimal('5825761.26')),
#  ('Eastern Africa', 'South Sudan', Decimal('631930.00'), Decimal('5825761.26')),
#  ('Eastern Africa', 'Somalia', Decimal('627340.00'), Decimal('5825761.26')),
#  ('Eastern Africa', 'Rwanda', Decimal('24670.00'), Decimal('5825761.26')),
#  ('Eastern Africa', 'Zimbabwe', Decimal('386850.00'), Decimal('5825761.26')),
#  ('Eastern Africa', 'Zambia', Decimal('743390.00'), Decimal('5825761.26')),
#  ('Eastern Asia', 'China', Decimal('9424702.90'), Decimal('11346709.70')),
#  ('Eastern Asia', 'Japan', Decimal('364500.00'), Decimal('11346709.70')),
#  ('Eastern Asia', 'Mongolia', Decimal('1557506.80'), Decimal('11346709.70')),
#  ('Melanesia', 'Vanuatu', Decimal('12190.00'), Decimal('529590.00')),
#  ('Melanesia', 'Fiji', Decimal('18270.00'), Decimal('529590.00')),
#  ('Melanesia', 'Solomon Islands', Decimal('27990.00'), Decimal('529590.00')),
#  ('Melanesia', 'Papua New Guinea', Decimal('452860.00'), Decimal('529590.00')),
#  ('Melanesia', 'New Caledonia', Decimal('18280.00'), Decimal('529590.00')),
#  ('Micronesia', 'Guam', Decimal('540.00'), Decimal('2470.00')),
#  ('Micronesia', 'Kiribati', Decimal('810.00'), Decimal('2470.00')),
#  ('Micronesia', 'Northern Mariana Islands', Decimal('460.00'), Decimal('2470.00')),
#  ('Micronesia', 'Palau', Decimal('460.00'), Decimal('2470.00')),
#  ('Micronesia', 'Nauru', Decimal('20.00'), Decimal('2470.00')),
#  ('Micronesia', 'Marshall Islands', Decimal('180.00'), Decimal('2470.00')),
#  ('Middle Africa', 'Angola', Decimal('1246700.00'), Decimal('3860220.00')),
#  ('Middle Africa', 'Cameroon', Decimal('472710.00'), Decimal('3860220.00')),
#  ('Middle Africa', 'Central African Republic', Decimal('622980.00'), Decimal('3860220.00')),
#  ('Middle Africa', 'Chad', Decimal('1259200.00'), Decimal('3860220.00')),
#  ('Middle Africa', 'Gabon', Decimal('257670.00'), Decimal('3860220.00')),
#  ('Middle Africa', 'Sao Tome and Principe', Decimal('960.00'), Decimal('3860220.00')),
#  ('Northern Africa', 'Algeria', Decimal('2381741.00'), Decimal('6610941.00')),
#  ('Northern Africa', 'Libya', Decimal('1759540.00'), Decimal('6610941.00')),
#  ('Northern Africa', 'Morocco', Decimal('446300.00'), Decimal('6610941.00')),
#  ('Northern Africa', 'Tunisia', Decimal('155360.00'), Decimal('6610941.00')),
#  ('Northern Africa', 'Sudan', Decimal('1868000.00'), Decimal('6610941.00')),
#  ('Northern America', 'Canada', Decimal('8965590.00'), Decimal('9376094.00')),
#  ('Northern America', 'Greenland', Decimal('410450.00'), Decimal('9376094.00')),
#  ('Northern America', 'Bermuda', Decimal('54.00'), Decimal('9376094.00')),
#  ('Polynesia', 'Tuvalu', Decimal('30.00'), Decimal('7201.00')),
#  ('Polynesia', 'Tonga', Decimal('720.00'), Decimal('7201.00')),
#  ('Polynesia', 'Samoa', Decimal('2780.00'), Decimal('7201.00')),
#  ('Polynesia', 'American Samoa', Decimal('200.00'), Decimal('7201.00')),
#  ('Polynesia', 'French Polynesia', Decimal('3471.00'), Decimal('7201.00')),
#  ('South America', 'Colombia', Decimal('1109500.00'), Decimal('15401392.00')),
#  ('South America', 'Ecuador', Decimal('248360.00'), Decimal('15401392.00')),
#  ('South America', 'Guyana', Decimal('196850.00'), Decimal('15401392.00')),
#  ('South America', 'Peru', Decimal('1280000.00'), Decimal('15401392.00')),
#  ('South America', 'Suriname', Decimal('156000.00'), Decimal('15401392.00')),
#  ('South America', 'Uruguay', Decimal('175020.00'), Decimal('15401392.00')),
#  ('South America', 'Paraguay', Decimal('397300.00'), Decimal('15401392.00')),
#  ('South America', 'Argentina', Decimal('2736690.00'), Decimal('15401392.00')),
#  ('South America', 'Brazil', Decimal('8358140.00'), Decimal('15401392.00')),
#  ('South America', 'Chile', Decimal('743532.00'), Decimal('15401392.00')),
#  ('South-Eastern Asia', 'Philippines', Decimal('298170.00'), Decimal('3865177.00')),
#  ('South-Eastern Asia', 'Cambodia', Decimal('176520.00'), Decimal('3865177.00')),
#  ('South-Eastern Asia', 'Timor-Leste', Decimal('14870.00'), Decimal('3865177.00')),
#  ('South-Eastern Asia', 'Thailand', Decimal('510890.00'), Decimal('3865177.00')),
#  ('South-Eastern Asia', 'Singapore', Decimal('718.00'), Decimal('3865177.00')),
#  ('South-Eastern Asia', 'Myanmar', Decimal('652670.00'), Decimal('3865177.00')),
#  ('South-Eastern Asia', 'Malaysia', Decimal('328550.00'), Decimal('3865177.00')),
#  ('South-Eastern Asia', 'Indonesia', Decimal('1877519.00'), Decimal('3865177.00')),
#  ('South-Eastern Asia', 'Brunei Darussalam', Decimal('5270.00'), Decimal('3865177.00')),
#  ('Southern Africa', 'Lesotho', Decimal('30360.00'), Decimal('2650670.00')),
#  ('Southern Africa', 'Eswatini', Decimal('17200.00'), Decimal('2650670.00')),
#  ('Southern Africa', 'Botswana', Decimal('566730.00'), Decimal('2650670.00')),
#  ('Southern Africa', 'South Africa', Decimal('1213090.00'), Decimal('2650670.00')),
#  ('Southern Africa', 'Namibia', Decimal('823290.00'), Decimal('2650670.00')),
#  ('Southern Asia', 'Pakistan', Decimal('770880.00'), Decimal('4770120.00')),
#  ('Southern Asia', 'Sri Lanka', Decimal('61860.00'), Decimal('4770120.00')),
#  ('Southern Asia', 'Nepal', Decimal('143350.00'), Decimal('4770120.00')),
#  ('Southern Asia', 'Maldives', Decimal('300.00'), Decimal('4770120.00')),
#  ('Southern Asia', 'India', Decimal('2973190.00'), Decimal('4770120.00')),
#  ('Southern Asia', 'Bhutan', Decimal('38140.00'), Decimal('4770120.00')),
#  ('Southern Asia', 'Bangladesh', Decimal('130170.00'), Decimal('4770120.00')),
#  ('Southern Asia', 'Afghanistan', Decimal('652230.00'), Decimal('4770120.00')),
#  ('Western Africa', 'Senegal', Decimal('192530.00'), Decimal('5735543.00')),
#  ('Western Africa', 'Sierra Leone', Decimal('72180.00'), Decimal('5735543.00')),
#  ('Western Africa', 'Togo', Decimal('54390.00'), Decimal('5735543.00')),
#  ('Western Africa', 'Mali', Decimal('1220190.00'), Decimal('5735543.00')),
#  ('Western Africa', 'Benin', Decimal('112760.00'), Decimal('5735543.00')),
#  ('Western Africa', 'Burkina Faso', Decimal('273600.00'), Decimal('5735543.00')),
#  ('Western Africa', 'Cabo Verde', Decimal('4030.00'), Decimal('5735543.00')),
#  ('Western Africa', 'Ghana', Decimal('227533.00'), Decimal('5735543.00')),
#  ('Western Africa', 'Guinea', Decimal('245720.00'), Decimal('5735543.00')),
#  ('Western Africa', 'Guinea-Bissau', Decimal('28120.00'), Decimal('5735543.00')),
#  ('Western Africa', 'Liberia', Decimal('96320.00'), Decimal('5735543.00')),
#  ('Western Africa', 'Mauritania', Decimal('1030700.00'), Decimal('5735543.00')),
#  ('Western Africa', 'Niger', Decimal('1266700.00'), Decimal('5735543.00')),
#  ('Western Africa', 'Nigeria', Decimal('910770.00'), Decimal('5735543.00')),
#  ('Western Asia', 'Jordan', Decimal('88794.00'), Decimal('3488573.00')),
#  ('Western Asia', 'Armenia', Decimal('28470.00'), Decimal('3488573.00')),
#  ('Western Asia', 'Kuwait', Decimal('17820.00'), Decimal('3488573.00')),
#  ('Western Asia', 'Georgia', Decimal('69490.00'), Decimal('3488573.00')),
#  ('Western Asia', 'Cyprus', Decimal('9240.00'), Decimal('3488573.00')),
#  ('Western Asia', 'Bahrain', Decimal('785.00'), Decimal('3488573.00')),
#  ('Western Asia', 'Azerbaijan', Decimal('82646.00'), Decimal('3488573.00')),
#  ('Western Asia', 'Syrian Arab Republic', Decimal('183630.00'), Decimal('3488573.00')),
#  ('Western Asia', 'United Arab Emirates', Decimal('71020.00'), Decimal('3488573.00')),
#  ('Western Asia', 'Saudi Arabia', Decimal('2149690.00'), Decimal('3488573.00')),
#  ('Western Asia', 'Qatar', Decimal('11490.00'), Decimal('3488573.00')),
#  ('Western Asia', 'Oman', Decimal('309500.00'), Decimal('3488573.00')),
#  ('Western Asia', 'Lebanon', Decimal('10230.00'), Decimal('3488573.00')),
#  ('Western Asia', 'Israel', Decimal('21640.00'), Decimal('3488573.00')),
#  ('Western Asia', 'Iraq', Decimal('434128.00'), Decimal('3488573.00'))]

# %% [markdown]
# ### Task 2: Calculate the land area covered as a percentage of the country's subregion
#
#
# Calculate each land area as a percentage within its sub_region:
# - Divide the `Land_area` by the `SUM()` `BY` the areas `OVER` each `Sub_region`'s `PARTITION`. Name this column `pct_sub_region_land_area`.
# - `Round` the calculation off to `4` decimal places.
#
# Add this line to the query from the first task.

# %%
# %%sql
# -- Add your code here
#
# SELECT
#     Sub_region,
#     Country_name,
#     Land_area,
#     ROUND(Land_area/ SUM(Land_area) OVER (
#         PARTITION BY Sub_region) *100) AS Pct_Sub_region_land_area
# FROM
#     access_to_basic_services
# WHERE
#     Time_period = 2020
# AND
#     Land_area IS NOT NULL;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/united_nations
# 130 rows affected.
# [('Australia and New Zealand', 'Australia', Decimal('7692020.00'), Decimal('97')),
#  ('Australia and New Zealand', 'New Zealand', Decimal('263310.00'), Decimal('3')),
#  ('Caribbean', 'Jamaica', Decimal('10830.00'), Decimal('5')),
#  ('Caribbean', 'Trinidad and Tobago', Decimal('5130.00'), Decimal('3')),
#  ('Caribbean', 'Barbados', Decimal('430.00'), Decimal('0')),
#  ('Caribbean', 'British Virgin Islands', Decimal('150.00'), Decimal('0')),
#  ('Caribbean', 'Cuba', Decimal('103800.00'), Decimal('51')),
#  ('Caribbean', 'Dominican Republic', Decimal('48310.00'), Decimal('24')),
#  ('Caribbean', 'Haiti', Decimal('27560.00'), Decimal('13')),
#  ('Caribbean', 'Puerto Rico', Decimal('8870.00'), Decimal('4')),
#  ('Central America', 'Nicaragua', Decimal('120340.00'), Decimal('5')),
#  ('Central America', 'Mexico', Decimal('1943950.00'), Decimal('79')),
#  ('Central America', 'Honduras', Decimal('111890.00'), Decimal('5')),
#  ('Central America', 'Guatemala', Decimal('107160.00'), Decimal('4')),
#  ('Central America', 'El Salvador', Decimal('20720.00'), Decimal('1')),
#  ('Central America', 'Panama', Decimal('74180.00'), Decimal('3')),
#  ('Central America', 'Costa Rica', Decimal('51060.00'), Decimal('2')),
#  ('Central America', 'Belize', Decimal('22810.00'), Decimal('1')),
#  ('Central Asia', 'Tajikistan', Decimal('138790.00'), Decimal('4')),
#  ('Central Asia', 'Turkmenistan', Decimal('469930.00'), Decimal('13')),
#  ('Central Asia', 'Uzbekistan', Decimal('440650.00'), Decimal('12')),
#  ('Central Asia', 'Kazakhstan', Decimal('2699700.00'), Decimal('72')),
#  ('Eastern Africa', 'Mauritius', Decimal('2030.00'), Decimal('0')),
#  ('Eastern Africa', 'Malawi', Decimal('94280.00'), Decimal('2')),
#  ('Eastern Africa', 'Madagascar', Decimal('581800.00'), Decimal('10')),
#  ('Eastern Africa', 'Kenya', Decimal('569140.00'), Decimal('10')),
#  ('Eastern Africa', 'Djibouti', Decimal('23180.00'), Decimal('0')),
#  ('Eastern Africa', 'Burundi', Decimal('25680.00'), Decimal('0')),
#  ('Eastern Africa', 'Uganda', Decimal('200520.00'), Decimal('3')),
#  ('Eastern Africa', 'Mozambique', Decimal('786380.00'), Decimal('13')),
#  ('Eastern Africa', 'Ethiopia', Decimal('1128571.26'), Decimal('19')),
#  ('Eastern Africa', 'South Sudan', Decimal('631930.00'), Decimal('11')),
#  ('Eastern Africa', 'Somalia', Decimal('627340.00'), Decimal('11')),
#  ('Eastern Africa', 'Rwanda', Decimal('24670.00'), Decimal('0')),
#  ('Eastern Africa', 'Zimbabwe', Decimal('386850.00'), Decimal('7')),
#  ('Eastern Africa', 'Zambia', Decimal('743390.00'), Decimal('13')),
#  ('Eastern Asia', 'China', Decimal('9424702.90'), Decimal('83')),
#  ('Eastern Asia', 'Japan', Decimal('364500.00'), Decimal('3')),
#  ('Eastern Asia', 'Mongolia', Decimal('1557506.80'), Decimal('14')),
#  ('Melanesia', 'Vanuatu', Decimal('12190.00'), Decimal('2')),
#  ('Melanesia', 'Fiji', Decimal('18270.00'), Decimal('3')),
#  ('Melanesia', 'Solomon Islands', Decimal('27990.00'), Decimal('5')),
#  ('Melanesia', 'Papua New Guinea', Decimal('452860.00'), Decimal('86')),
#  ('Melanesia', 'New Caledonia', Decimal('18280.00'), Decimal('3')),
#  ('Micronesia', 'Guam', Decimal('540.00'), Decimal('22')),
#  ('Micronesia', 'Kiribati', Decimal('810.00'), Decimal('33')),
#  ('Micronesia', 'Northern Mariana Islands', Decimal('460.00'), Decimal('19')),
#  ('Micronesia', 'Palau', Decimal('460.00'), Decimal('19')),
#  ('Micronesia', 'Nauru', Decimal('20.00'), Decimal('1')),
#  ('Micronesia', 'Marshall Islands', Decimal('180.00'), Decimal('7')),
#  ('Middle Africa', 'Angola', Decimal('1246700.00'), Decimal('32')),
#  ('Middle Africa', 'Cameroon', Decimal('472710.00'), Decimal('12')),
#  ('Middle Africa', 'Central African Republic', Decimal('622980.00'), Decimal('16')),
#  ('Middle Africa', 'Chad', Decimal('1259200.00'), Decimal('33')),
#  ('Middle Africa', 'Gabon', Decimal('257670.00'), Decimal('7')),
#  ('Middle Africa', 'Sao Tome and Principe', Decimal('960.00'), Decimal('0')),
#  ('Northern Africa', 'Algeria', Decimal('2381741.00'), Decimal('36')),
#  ('Northern Africa', 'Libya', Decimal('1759540.00'), Decimal('27')),
#  ('Northern Africa', 'Morocco', Decimal('446300.00'), Decimal('7')),
#  ('Northern Africa', 'Tunisia', Decimal('155360.00'), Decimal('2')),
#  ('Northern Africa', 'Sudan', Decimal('1868000.00'), Decimal('28')),
#  ('Northern America', 'Canada', Decimal('8965590.00'), Decimal('96')),
#  ('Northern America', 'Greenland', Decimal('410450.00'), Decimal('4')),
#  ('Northern America', 'Bermuda', Decimal('54.00'), Decimal('0')),
#  ('Polynesia', 'Tuvalu', Decimal('30.00'), Decimal('0')),
#  ('Polynesia', 'Tonga', Decimal('720.00'), Decimal('10')),
#  ('Polynesia', 'Samoa', Decimal('2780.00'), Decimal('39')),
#  ('Polynesia', 'American Samoa', Decimal('200.00'), Decimal('3')),
#  ('Polynesia', 'French Polynesia', Decimal('3471.00'), Decimal('48')),
#  ('South America', 'Colombia', Decimal('1109500.00'), Decimal('7')),
#  ('South America', 'Ecuador', Decimal('248360.00'), Decimal('2')),
#  ('South America', 'Guyana', Decimal('196850.00'), Decimal('1')),
#  ('South America', 'Peru', Decimal('1280000.00'), Decimal('8')),
#  ('South America', 'Suriname', Decimal('156000.00'), Decimal('1')),
#  ('South America', 'Uruguay', Decimal('175020.00'), Decimal('1')),
#  ('South America', 'Paraguay', Decimal('397300.00'), Decimal('3')),
#  ('South America', 'Argentina', Decimal('2736690.00'), Decimal('18')),
#  ('South America', 'Brazil', Decimal('8358140.00'), Decimal('54')),
#  ('South America', 'Chile', Decimal('743532.00'), Decimal('5')),
#  ('South-Eastern Asia', 'Philippines', Decimal('298170.00'), Decimal('8')),
#  ('South-Eastern Asia', 'Cambodia', Decimal('176520.00'), Decimal('5')),
#  ('South-Eastern Asia', 'Timor-Leste', Decimal('14870.00'), Decimal('0')),
#  ('South-Eastern Asia', 'Thailand', Decimal('510890.00'), Decimal('13')),
#  ('South-Eastern Asia', 'Singapore', Decimal('718.00'), Decimal('0')),
#  ('South-Eastern Asia', 'Myanmar', Decimal('652670.00'), Decimal('17')),
#  ('South-Eastern Asia', 'Malaysia', Decimal('328550.00'), Decimal('9')),
#  ('South-Eastern Asia', 'Indonesia', Decimal('1877519.00'), Decimal('49')),
#  ('South-Eastern Asia', 'Brunei Darussalam', Decimal('5270.00'), Decimal('0')),
#  ('Southern Africa', 'Lesotho', Decimal('30360.00'), Decimal('1')),
#  ('Southern Africa', 'Eswatini', Decimal('17200.00'), Decimal('1')),
#  ('Southern Africa', 'Botswana', Decimal('566730.00'), Decimal('21')),
#  ('Southern Africa', 'South Africa', Decimal('1213090.00'), Decimal('46')),
#  ('Southern Africa', 'Namibia', Decimal('823290.00'), Decimal('31')),
#  ('Southern Asia', 'Pakistan', Decimal('770880.00'), Decimal('16')),
#  ('Southern Asia', 'Sri Lanka', Decimal('61860.00'), Decimal('1')),
#  ('Southern Asia', 'Nepal', Decimal('143350.00'), Decimal('3')),
#  ('Southern Asia', 'Maldives', Decimal('300.00'), Decimal('0')),
#  ('Southern Asia', 'India', Decimal('2973190.00'), Decimal('62')),
#  ('Southern Asia', 'Bhutan', Decimal('38140.00'), Decimal('1')),
#  ('Southern Asia', 'Bangladesh', Decimal('130170.00'), Decimal('3')),
#  ('Southern Asia', 'Afghanistan', Decimal('652230.00'), Decimal('14')),
#  ('Western Africa', 'Senegal', Decimal('192530.00'), Decimal('3')),
#  ('Western Africa', 'Sierra Leone', Decimal('72180.00'), Decimal('1')),
#  ('Western Africa', 'Togo', Decimal('54390.00'), Decimal('1')),
#  ('Western Africa', 'Mali', Decimal('1220190.00'), Decimal('21')),
#  ('Western Africa', 'Benin', Decimal('112760.00'), Decimal('2')),
#  ('Western Africa', 'Burkina Faso', Decimal('273600.00'), Decimal('5')),
#  ('Western Africa', 'Cabo Verde', Decimal('4030.00'), Decimal('0')),
#  ('Western Africa', 'Ghana', Decimal('227533.00'), Decimal('4')),
#  ('Western Africa', 'Guinea', Decimal('245720.00'), Decimal('4')),
#  ('Western Africa', 'Guinea-Bissau', Decimal('28120.00'), Decimal('0')),
#  ('Western Africa', 'Liberia', Decimal('96320.00'), Decimal('2')),
#  ('Western Africa', 'Mauritania', Decimal('1030700.00'), Decimal('18')),
#  ('Western Africa', 'Niger', Decimal('1266700.00'), Decimal('22')),
#  ('Western Africa', 'Nigeria', Decimal('910770.00'), Decimal('16')),
#  ('Western Asia', 'Jordan', Decimal('88794.00'), Decimal('3')),
#  ('Western Asia', 'Armenia', Decimal('28470.00'), Decimal('1')),
#  ('Western Asia', 'Kuwait', Decimal('17820.00'), Decimal('1')),
#  ('Western Asia', 'Georgia', Decimal('69490.00'), Decimal('2')),
#  ('Western Asia', 'Cyprus', Decimal('9240.00'), Decimal('0')),
#  ('Western Asia', 'Bahrain', Decimal('785.00'), Decimal('0')),
#  ('Western Asia', 'Azerbaijan', Decimal('82646.00'), Decimal('2')),
#  ('Western Asia', 'Syrian Arab Republic', Decimal('183630.00'), Decimal('5')),
#  ('Western Asia', 'United Arab Emirates', Decimal('71020.00'), Decimal('2')),
#  ('Western Asia', 'Saudi Arabia', Decimal('2149690.00'), Decimal('62')),
#  ('Western Asia', 'Qatar', Decimal('11490.00'), Decimal('0')),
#  ('Western Asia', 'Oman', Decimal('309500.00'), Decimal('9')),
#  ('Western Asia', 'Lebanon', Decimal('10230.00'), Decimal('0')),
#  ('Western Asia', 'Israel', Decimal('21640.00'), Decimal('1')),
#  ('Western Asia', 'Iraq', Decimal('434128.00'), Decimal('12'))]

# %% [markdown]
# ### Task 3: Calculate The running population average for each country's subregion
#
# Start by selecting the columns needed for this analysis:
# - `Sub_region`
# - `Country_name`
# - `Time_period`
# - `Pct_managed_drinking_water_services`
# - `Pct_managed_sanitation_services`
# - `Est_gdp_in_billions`
# - `Est_population_in_millions`
#
# Calculate the running average:
# - Calculate the `AVG()` of the `Est_population_in_millions`.
# - `PARTITION` the calculation `OVER` each country's `Sub_region`, and name this column `Running_average_population`.
# - `ROUND` the calculation off to `4` decimal places.
# - Filter the results `WHERE` there are values of `Est_gdp_in_billions` that are `NOT NULL`.

# %%
# %%sql
# -- Add your code here
#
# SELECT
#     Sub_region,
#     Country_name,
#     Time_period,
#     Est_population_in_millions,
#     ROUND(AVG(Est_population_in_millions) OVER(
#         PARTITION BY Sub_region
#         ORDER BY Time_period), 4) AS Running_avg_population
# FROM
#     access_to_basic_services
# WHERE
#     Est_population_in_millions IS NOT NULL;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/united_nations
# 815 rows affected.
# [('Australia and New Zealand', 'New Zealand', 2015, Decimal('4.609400'), Decimal('14.2127')),
#  ('Australia and New Zealand', 'Australia', 2015, Decimal('23.815995'), Decimal('14.2127')),
#  ('Australia and New Zealand', 'New Zealand', 2016, Decimal('4.714100'), Decimal('14.3326')),
#  ('Australia and New Zealand', 'Australia', 2016, Decimal('24.190907'), Decimal('14.3326')),
#  ('Australia and New Zealand', 'Australia', 2017, Decimal('24.594202'), Decimal('14.4564')),
#  ('Australia and New Zealand', 'New Zealand', 2017, Decimal('4.813600'), Decimal('14.4564')),
#  ('Australia and New Zealand', 'Australia', 2018, Decimal('24.966643'), Decimal('14.5757')),
#  ('Australia and New Zealand', 'New Zealand', 2018, Decimal('4.900600'), Decimal('14.5757')),
#  ('Australia and New Zealand', 'Australia', 2019, Decimal('25.340217'), Decimal('14.6925')),
#  ('Australia and New Zealand', 'New Zealand', 2019, Decimal('4.979200'), Decimal('14.6925')),
#  ('Australia and New Zealand', 'Australia', 2020, Decimal('25.655289'), Decimal('14.8059')),
#  ('Australia and New Zealand', 'New Zealand', 2020, Decimal('5.090200'), Decimal('14.8059')),
#  ('Caribbean', 'Trinidad and Tobago', 2015, Decimal('1.460177'), Decimal('2.7243')),
#  ('Caribbean', 'Cayman Islands', 2015, Decimal('0.060911'), Decimal('2.7243')),
#  ('Caribbean', 'Puerto Rico', 2015, Decimal('3.473232'), Decimal('2.7243')),
#  ('Caribbean', 'Jamaica', 2015, Decimal('2.794445'), Decimal('2.7243')),
#  ('Caribbean', 'Turks and Caicos Islands', 2015, Decimal('0.036538'), Decimal('2.7243')),
#  ('Caribbean', 'Grenada', 2015, Decimal('0.118980'), Decimal('2.7243')),
#  ('Caribbean', 'Aruba', 2015, Decimal('0.104257'), Decimal('2.7243')),
#  ('Caribbean', 'Antigua and Barbuda', 2015, Decimal('0.089941'), Decimal('2.7243')),
#  ('Caribbean', 'Haiti', 2015, Decimal('10.563757'), Decimal('2.7243')),
#  ('Caribbean', 'Dominican Republic', 2015, Decimal('10.405832'), Decimal('2.7243')),
#  ('Caribbean', 'British Virgin Islands', 2015, Decimal('0.029366'), Decimal('2.7243')),
#  ('Caribbean', 'Barbados', 2015, Decimal('0.278083'), Decimal('2.7243')),
#  ('Caribbean', 'Sint Maarten (Dutch part)', 2015, Decimal('0.038825'), Decimal('2.7243')),
#  ('Caribbean', 'Cuba', 2015, Decimal('11.339894'), Decimal('2.7243')),
#  ('Caribbean', 'Dominica', 2015, Decimal('0.070007'), Decimal('2.7243')),
#  ('Caribbean', 'Grenada', 2016, Decimal('0.119966'), Decimal('2.7320')),
#  ('Caribbean', 'Aruba', 2016, Decimal('0.104874'), Decimal('2.7320')),
#  ('Caribbean', 'Turks and Caicos Islands', 2016, Decimal('0.038246'), Decimal('2.7320')),
#  ('Caribbean', 'Trinidad and Tobago', 2016, Decimal('1.469330'), Decimal('2.7320')),
#  ('Caribbean', 'Sint Maarten (Dutch part)', 2016, Decimal('0.039969'), Decimal('2.7320')),
#  ('Caribbean', 'Barbados', 2016, Decimal('0.278649'), Decimal('2.7320')),
#  ('Caribbean', 'Antigua and Barbuda', 2016, Decimal('0.090564'), Decimal('2.7320')),
#  ('Caribbean', 'Haiti', 2016, Decimal('10.713849'), Decimal('2.7320')),
#  ('Caribbean', 'Puerto Rico', 2016, Decimal('3.406672'), Decimal('2.7320')),
#  ('Caribbean', 'British Virgin Islands', 2016, Decimal('0.029739'), Decimal('2.7320')),
#  ('Caribbean', 'Cayman Islands', 2016, Decimal('0.062255'), Decimal('2.7320')),
#  ('Caribbean', 'Dominican Republic', 2016, Decimal('10.527592'), Decimal('2.7320')),
#  ('Caribbean', 'Cuba', 2016, Decimal('11.342012'), Decimal('2.7320')),
#  ('Caribbean', 'Jamaica', 2016, Decimal('2.802695'), Decimal('2.7320')),
#  ('Caribbean', 'Dominica', 2016, Decimal('0.070075'), Decimal('2.7320')),
#  ('Caribbean', 'Sint Maarten (Dutch part)', 2017, Decimal('0.040574'), Decimal('2.8626')),
#  ('Caribbean', 'Antigua and Barbuda', 2017, Decimal('0.091119'), Decimal('2.8626')),
#  ('Caribbean', 'Grenada', 2017, Decimal('0.120921'), Decimal('2.8626')),
#  ('Caribbean', 'Haiti', 2017, Decimal('10.863543'), Decimal('2.8626')),
#  ('Caribbean', 'Dominican Republic', 2017, Decimal('10.647244'), Decimal('2.8626')),
#  ('Caribbean', 'Puerto Rico', 2017, Decimal('3.325286'), Decimal('2.8626')),
#  ('Caribbean', 'British Virgin Islands', 2017, Decimal('0.030060'), Decimal('2.8626')),
#  ('Caribbean', 'Trinidad and Tobago', 2017, Decimal('1.478607'), Decimal('2.8626')),
#  ('Caribbean', 'Turks and Caicos Islands', 2017, Decimal('0.039844'), Decimal('2.8626')),
#  ('Caribbean', 'Barbados', 2017, Decimal('0.279187'), Decimal('2.8626')),
#  ('Caribbean', 'Jamaica', 2017, Decimal('2.808376'), Decimal('2.8626')),
#  ('Caribbean', 'Dominica', 2017, Decimal('0.070403'), Decimal('2.8626')),
#  ('Caribbean', 'Cuba', 2017, Decimal('11.336405'), Decimal('2.8626')),
#  ('Caribbean', 'Barbados', 2018, Decimal('0.279688'), Decimal('3.1550')),
#  ('Caribbean', 'Puerto Rico', 2018, Decimal('3.193354'), Decimal('3.1550')),
#  ('Caribbean', 'Haiti', 2018, Decimal('11.012421'), Decimal('3.1550')),
#  ('Caribbean', 'British Virgin Islands', 2018, Decimal('0.030335'), Decimal('3.1550')),
#  ('Caribbean', 'Dominican Republic', 2018, Decimal('10.765531'), Decimal('3.1550')),
#  ('Caribbean', 'Trinidad and Tobago', 2018, Decimal('1.504709'), Decimal('3.1550')),
#  ('Caribbean', 'Turks and Caicos Islands', 2018, Decimal('0.041487'), Decimal('3.1550')),
#  ('Caribbean', 'Cuba', 2018, Decimal('11.328244'), Decimal('3.1550')),
#  ('Caribbean', 'Jamaica', 2018, Decimal('2.811835'), Decimal('3.1550')),
#  ('Caribbean', 'Trinidad and Tobago', 2019, Decimal('1.519955'), Decimal('3.4210')),
#  ('Caribbean', 'Barbados', 2019, Decimal('0.280180'), Decimal('3.4210')),
#  ('Caribbean', 'British Virgin Islands', 2019, Decimal('0.030610'), Decimal('3.4210')),
#  ('Caribbean', 'Dominican Republic', 2019, Decimal('10.881882'), Decimal('3.4210')),
#  ('Caribbean', 'Cuba', 2019, Decimal('11.316697'), Decimal('3.4210')),
#  ('Caribbean', 'Jamaica', 2019, Decimal('2.813773'), Decimal('3.4210')),
#  ('Caribbean', 'Puerto Rico', 2019, Decimal('3.193694'), Decimal('3.4210')),
#  ('Caribbean', 'Haiti', 2019, Decimal('11.160438'), Decimal('3.4210')),
#  ('Caribbean', 'Haiti', 2020, Decimal('11.306801'), Decimal('3.6294')),
#  ('Caribbean', 'Trinidad and Tobago', 2020, Decimal('1.518147'), Decimal('3.6294')),
#  ('Caribbean', 'Cuba', 2020, Decimal('11.300698'), Decimal('3.6294')),
#  ('Caribbean', 'Jamaica', 2020, Decimal('2.820436'), Decimal('3.6294')),
#  ('Caribbean', 'British Virgin Islands', 2020, Decimal('0.030910'), Decimal('3.6294')),
#  ('Caribbean', 'Barbados', 2020, Decimal('0.280693'), Decimal('3.6294')),
#  ('Caribbean', 'Puerto Rico', 2020, Decimal('3.281538'), Decimal('3.6294')),
#  ('Caribbean', 'Dominican Republic', 2020, Decimal('10.999664'), Decimal('3.6294')),
#  ('Central America', 'Costa Rica', 2015, Decimal('4.895242'), Decimal('20.8442')),
#  ('Central America', 'Honduras', 2015, Decimal('9.294505'), Decimal('20.8442')),
#  ('Central America', 'Panama', 2015, Decimal('3.957099'), Decimal('20.8442')),
#  ('Central America', 'Belize', 2015, Decimal('0.359871'), Decimal('20.8442')),
#  ('Central America', 'Nicaragua', 2015, Decimal('6.298598'), Decimal('20.8442')),
#  ('Central America', 'Guatemala', 2015, Decimal('15.567419'), Decimal('20.8442')),
#  ('Central America', 'El Salvador', 2015, Decimal('6.231066'), Decimal('20.8442')),
#  ('Central America', 'Mexico', 2015, Decimal('120.149897'), Decimal('20.8442')),
#  ('Central America', 'Mexico', 2016, Decimal('121.519221'), Decimal('20.9713')),
#  ('Central America', 'Nicaragua', 2016, Decimal('6.389235'), Decimal('20.9713')),
#  ('Central America', 'Honduras', 2016, Decimal('9.460798'), Decimal('20.9713')),
#  ('Central America', 'Panama', 2016, Decimal('4.026336'), Decimal('20.9713')),
#  ('Central America', 'Guatemala', 2016, Decimal('15.827690'), Decimal('20.9713')),
#  ('Central America', 'Belize', 2016, Decimal('0.367313'), Decimal('20.9713')),
#  ('Central America', 'Costa Rica', 2016, Decimal('4.945205'), Decimal('20.9713')),
#  ('Central America', 'El Salvador', 2016, Decimal('6.250510'), Decimal('20.9713')),
#  ('Central America', 'Costa Rica', 2017, Decimal('4.993842'), Decimal('21.0961')),
#  ('Central America', 'Honduras', 2017, Decimal('9.626842'), Decimal('21.0961')),
#  ('Central America', 'Panama', 2017, Decimal('4.096063'), Decimal('21.0961')),
#  ('Central America', 'Nicaragua', 2017, Decimal('6.480532'), Decimal('21.0961')),
#  ('Central America', 'Mexico', 2017, Decimal('122.839258'), Decimal('21.0961')),
#  ('Central America', 'Guatemala', 2017, Decimal('16.087418'), Decimal('21.0961')),
#  ('Central America', 'El Salvador', 2017, Decimal('6.266654'), Decimal('21.0961')),
#  ('Central America', 'Belize', 2017, Decimal('0.374693'), Decimal('21.0961')),
#  ('Central America', 'Nicaragua', 2018, Decimal('6.572233'), Decimal('21.2155')),
#  ('Central America', 'El Salvador', 2018, Decimal('6.276342'), Decimal('21.2155')),
#  ('Central America', 'Costa Rica', 2018, Decimal('5.040734'), Decimal('21.2155')),
#  ('Central America', 'Belize', 2018, Decimal('0.382066'), Decimal('21.2155')),
#  ('Central America', 'Panama', 2018, Decimal('4.165255'), Decimal('21.2155')),
#  ('Central America', 'Mexico', 2018, Decimal('124.013861'), Decimal('21.2155')),
#  ('Central America', 'Guatemala', 2018, Decimal('16.346950'), Decimal('21.2155')),
#  ('Central America', 'Honduras', 2018, Decimal('9.792850'), Decimal('21.2155')),
#  ('Central America', 'Panama', 2019, Decimal('4.232532'), Decimal('21.3299')),
#  ('Central America', 'Nicaragua', 2019, Decimal('6.663924'), Decimal('21.3299')),
#  ('Central America', 'El Salvador', 2019, Decimal('6.280217'), Decimal('21.3299')),
#  ('Central America', 'Belize', 2019, Decimal('0.389095'), Decimal('21.3299')),
#  ('Central America', 'Costa Rica', 2019, Decimal('5.084532'), Decimal('21.3299')),
#  ('Central America', 'Mexico', 2019, Decimal('125.085311'), Decimal('21.3299')),
#  ('Central America', 'Guatemala', 2019, Decimal('16.604026'), Decimal('21.3299')),
#  ('Central America', 'Honduras', 2019, Decimal('9.958829'), Decimal('21.3299')),
#  ('Central America', 'Costa Rica', 2020, Decimal('5.123105'), Decimal('21.4382')),
#  ('Central America', 'Nicaragua', 2020, Decimal('6.755895'), Decimal('21.4382')),
#  ('Central America', 'El Salvador', 2020, Decimal('6.292731'), Decimal('21.4382')),
#  ('Central America', 'Panama', 2020, Decimal('4.294396'), Decimal('21.4382')),
#  ('Central America', 'Guatemala', 2020, Decimal('16.858333'), Decimal('21.4382')),
#  ('Central America', 'Mexico', 2020, Decimal('125.998302'), Decimal('21.4382')),
#  ('Central America', 'Honduras', 2020, Decimal('10.121763'), Decimal('21.4382')),
#  ('Central America', 'Belize', 2020, Decimal('0.394921'), Decimal('21.4382')),
#  ('Central Asia', 'Tajikistan', 2015, Decimal('8.524063'), Decimal('15.7831')),
#  ('Central Asia', 'Turkmenistan', 2015, Decimal('5.766431'), Decimal('15.7831')),
#  ('Central Asia', 'Kazakhstan', 2015, Decimal('17.542806'), Decimal('15.7831')),
#  ('Central Asia', 'Uzbekistan', 2015, Decimal('31.298900'), Decimal('15.7831')),
#  ('Central Asia', 'Kazakhstan', 2016, Decimal('17.794055'), Decimal('15.9210')),
#  ('Central Asia', 'Tajikistan', 2016, Decimal('8.725318'), Decimal('15.9210')),
#  ('Central Asia', 'Uzbekistan', 2016, Decimal('31.847900'), Decimal('15.9210')),
#  ('Central Asia', 'Turkmenistan', 2016, Decimal('5.868561'), Decimal('15.9210')),
#  ('Central Asia', 'Kazakhstan', 2017, Decimal('18.037776'), Decimal('16.0574')),
#  ('Central Asia', 'Tajikistan', 2017, Decimal('8.925525'), Decimal('16.0574')),
#  ('Central Asia', 'Uzbekistan', 2017, Decimal('32.388600'), Decimal('16.0574')),
#  ('Central Asia', 'Turkmenistan', 2017, Decimal('5.968383'), Decimal('16.0574')),
#  ('Central Asia', 'Turkmenistan', 2018, Decimal('6.065066'), Decimal('16.1946')),
#  ('Central Asia', 'Uzbekistan', 2018, Decimal('32.956100'), Decimal('16.1946')),
#  ('Central Asia', 'Tajikistan', 2018, Decimal('9.128132'), Decimal('16.1946')),
#  ('Central Asia', 'Kazakhstan', 2018, Decimal('18.276452'), Decimal('16.1946')),
#  ('Central Asia', 'Tajikistan', 2019, Decimal('9.337003'), Decimal('16.3352')),
#  ('Central Asia', 'Turkmenistan', 2019, Decimal('6.158420'), Decimal('16.3352')),
#  ('Central Asia', 'Uzbekistan', 2019, Decimal('33.580350'), Decimal('16.3352')),
#  ('Central Asia', 'Kazakhstan', 2019, Decimal('18.513673'), Decimal('16.3352')),
#  ('Central Asia', 'Turkmenistan', 2020, Decimal('6.250438'), Decimal('16.4785')),
#  ('Central Asia', 'Tajikistan', 2020, Decimal('9.543207'), Decimal('16.4785')),
#  ('Central Asia', 'Uzbekistan', 2020, Decimal('34.232050'), Decimal('16.4785')),
#  ('Central Asia', 'Kazakhstan', 2020, Decimal('18.755666'), Decimal('16.4785')),
#  ('Eastern Africa', 'Mauritius', 2015, Decimal('1.262605'), Decimal('19.9763')),
#  ('Eastern Africa', 'Burundi', 2015, Decimal('10.727148'), Decimal('19.9763')),
#  ('Eastern Africa', 'Kenya', 2015, Decimal('46.851488'), Decimal('19.9763')),
#  ('Eastern Africa', 'Djibouti', 2015, Decimal('1.006259'), Decimal('19.9763')),
#  ('Eastern Africa', 'South Sudan', 2015, Decimal('11.194299'), Decimal('19.9763')),
#  ('Eastern Africa', 'Uganda', 2015, Decimal('37.477356'), Decimal('19.9763')),
#  ('Eastern Africa', 'Malawi', 2015, Decimal('16.938942'), Decimal('19.9763')),
#  ('Eastern Africa', 'Zambia', 2015, Decimal('16.248230'), Decimal('19.9763')),
#  ('Eastern Africa', 'Zimbabwe', 2015, Decimal('14.154937'), Decimal('19.9763')),
#  ('Eastern Africa', 'Ethiopia', 2015, Decimal('102.471895'), Decimal('19.9763')),
#  ('Eastern Africa', 'Comoros', 2015, Decimal('0.730216'), Decimal('19.9763')),
#  ('Eastern Africa', 'Eritrea', 2015, Decimal('3.340006'), Decimal('19.9763')),
#  ('Eastern Africa', 'Madagascar', 2015, Decimal('24.850912'), Decimal('19.9763')),
#  ('Eastern Africa', 'Mozambique', 2015, Decimal('26.843246'), Decimal('19.9763')),
#  ('Eastern Africa', 'Rwanda', 2015, Decimal('11.642959'), Decimal('19.9763')),
#  ('Eastern Africa', 'Seychelles', 2015, Decimal('0.093419'), Decimal('19.9763')),
#  ('Eastern Africa', 'Somalia', 2015, Decimal('13.763906'), Decimal('19.9763')),
#  ('Eastern Africa', 'Eritrea', 2016, Decimal('3.365287'), Decimal('20.2366')),
#  ('Eastern Africa', 'Burundi', 2016, Decimal('10.903327'), Decimal('20.2366')),
#  ('Eastern Africa', 'South Sudan', 2016, Decimal('11.066105'), Decimal('20.2366')),
#  ('Eastern Africa', 'Uganda', 2016, Decimal('38.748299'), Decimal('20.2366')),
#  ('Eastern Africa', 'Malawi', 2016, Decimal('17.405624'), Decimal('20.2366')),
#  ('Eastern Africa', 'Seychelles', 2016, Decimal('0.094677'), Decimal('20.2366')),
#  ('Eastern Africa', 'Zambia', 2016, Decimal('16.767761'), Decimal('20.2366')),
#  ('Eastern Africa', 'Mozambique', 2016, Decimal('27.696493'), Decimal('20.2366')),
#  ('Eastern Africa', 'Comoros', 2016, Decimal('0.746232'), Decimal('20.2366')),
#  ('Eastern Africa', 'Madagascar', 2016, Decimal('25.501941'), Decimal('20.2366')),
#  ('Eastern Africa', 'Ethiopia', 2016, Decimal('105.293228'), Decimal('20.2366')),
#  ('Eastern Africa', 'Somalia', 2016, Decimal('14.292847'), Decimal('20.2366')),
#  ('Eastern Africa', 'Rwanda', 2016, Decimal('11.930899'), Decimal('20.2366')),
#  ('Eastern Africa', 'Djibouti', 2016, Decimal('1.023261'), Decimal('20.2366')),
#  ('Eastern Africa', 'Kenya', 2016, Decimal('47.894670'), Decimal('20.2366')),
#  ('Eastern Africa', 'Mauritius', 2016, Decimal('1.263473'), Decimal('20.2366')),
#  ('Eastern Africa', 'Zimbabwe', 2016, Decimal('14.452704'), Decimal('20.2366')),
#  ('Eastern Africa', 'Seychelles', 2017, Decimal('0.095843'), Decimal('20.8412')),
#  ('Eastern Africa', 'Madagascar', 2017, Decimal('26.169542'), Decimal('20.8412')),
#  ('Eastern Africa', 'Mauritius', 2017, Decimal('1.264613'), Decimal('20.8412')),
#  ('Eastern Africa', 'South Sudan', 2017, Decimal('10.658226'), Decimal('20.8412')),
#  ('Eastern Africa', 'Kenya', 2017, Decimal('48.948137'), Decimal('20.8412')),
#  ('Eastern Africa', 'Ethiopia', 2017, Decimal('108.197950'), Decimal('20.8412')),
#  ('Eastern Africa', 'Somalia', 2017, Decimal('14.864221'), Decimal('20.8412')),
#  ('Eastern Africa', 'Djibouti', 2017, Decimal('1.040233'), Decimal('20.8412')),
#  ('Eastern Africa', 'Comoros', 2017, Decimal('0.761664'), Decimal('20.8412')),
#  ('Eastern Africa', 'Uganda', 2017, Decimal('40.127085'), Decimal('20.8412')),
#  ('Eastern Africa', 'Burundi', 2017, Decimal('11.155593'), Decimal('20.8412')),
#  ('Eastern Africa', 'Mozambique', 2017, Decimal('28.569441'), Decimal('20.8412')),
#  ('Eastern Africa', 'Rwanda', 2017, Decimal('12.230339'), Decimal('20.8412')),
#  ('Eastern Africa', 'Zimbabwe', 2017, Decimal('14.751101'), Decimal('20.8412')),
#  ('Eastern Africa', 'Malawi', 2017, Decimal('17.881167'), Decimal('20.8412')),
#  ('Eastern Africa', 'Zambia', 2017, Decimal('17.298054'), Decimal('20.8412')),
#  ('Eastern Africa', 'Comoros', 2018, Decimal('0.776313'), Decimal('21.2911')),
#  ('Eastern Africa', 'Ethiopia', 2018, Decimal('111.129438'), Decimal('21.2911')),
#  ('Eastern Africa', 'Rwanda', 2018, Decimal('12.531808'), Decimal('21.2911')),
#  ('Eastern Africa', 'Seychelles', 2018, Decimal('0.096762'), Decimal('21.2911')),
#  ('Eastern Africa', 'Kenya', 2018, Decimal('49.953304'), Decimal('21.2911')),
#  ('Eastern Africa', 'Mozambique', 2018, Decimal('29.423878'), Decimal('21.2911')),
#  ('Eastern Africa', 'Djibouti', 2018, Decimal('1.057198'), Decimal('21.2911')),
#  ('Eastern Africa', 'Madagascar', 2018, Decimal('26.846541'), Decimal('21.2911')),
#  ('Eastern Africa', 'Mauritius', 2018, Decimal('1.265303'), Decimal('21.2911')),
#  ('Eastern Africa', 'Uganda', 2018, Decimal('41.515395'), Decimal('21.2911')),
#  ('Eastern Africa', 'Malawi', 2018, Decimal('18.367883'), Decimal('21.2911')),
#  ('Eastern Africa', 'Zimbabwe', 2018, Decimal('15.052184'), Decimal('21.2911')),
#  ('Eastern Africa', 'Somalia', 2018, Decimal('15.411094'), Decimal('21.2911')),
#  ('Eastern Africa', 'South Sudan', 2018, Decimal('10.395329'), Decimal('21.2911')),
#  ('Eastern Africa', 'Zambia', 2018, Decimal('17.835893'), Decimal('21.2911')),
#  ('Eastern Africa', 'Burundi', 2018, Decimal('11.493472'), Decimal('21.2911')),
#  ('Eastern Africa', 'Ethiopia', 2019, Decimal('114.120594'), Decimal('21.6832')),
#  ('Eastern Africa', 'Zimbabwe', 2019, Decimal('15.354608'), Decimal('21.6832')),
#  ('Eastern Africa', 'Mozambique', 2019, Decimal('30.285595'), Decimal('21.6832')),
#  ('Eastern Africa', 'Djibouti', 2019, Decimal('1.073994'), Decimal('21.6832')),
#  ('Eastern Africa', 'Comoros', 2019, Decimal('0.790986'), Decimal('21.6832')),
#  ('Eastern Africa', 'Uganda', 2019, Decimal('42.949080'), Decimal('21.6832')),
#  ('Eastern Africa', 'Mauritius', 2019, Decimal('1.265711'), Decimal('21.6832')),
#  ('Eastern Africa', 'Burundi', 2019, Decimal('11.874838'), Decimal('21.6832')),
#  ('Eastern Africa', 'South Sudan', 2019, Decimal('10.447666'), Decimal('21.6832')),
#  ('Eastern Africa', 'Somalia', 2019, Decimal('15.981300'), Decimal('21.6832')),
#  ('Eastern Africa', 'Seychelles', 2019, Decimal('0.097625'), Decimal('21.6832')),
#  ('Eastern Africa', 'Malawi', 2019, Decimal('18.867337'), Decimal('21.6832')),
#  ('Eastern Africa', 'Rwanda', 2019, Decimal('12.835028'), Decimal('21.6832')),
#  ('Eastern Africa', 'Zambia', 2019, Decimal('18.380477'), Decimal('21.6832')),
#  ('Eastern Africa', 'Madagascar', 2019, Decimal('27.533134'), Decimal('21.6832')),
#  ('Eastern Africa', 'Kenya', 2019, Decimal('50.951450'), Decimal('21.6832')),
#  ('Eastern Africa', 'Djibouti', 2020, Decimal('1.090156'), Decimal('22.4984')),
#  ('Eastern Africa', 'Kenya', 2020, Decimal('51.985780'), Decimal('22.4984')),
#  ('Eastern Africa', 'Mozambique', 2020, Decimal('31.178239'), Decimal('22.4984')),
#  ('Eastern Africa', 'Mauritius', 2020, Decimal('1.265740'), Decimal('22.4984')),
#  ('Eastern Africa', 'Ethiopia', 2020, Decimal('117.190911'), Decimal('22.4984')),
#  ('Eastern Africa', 'Madagascar', 2020, Decimal('28.225177'), Decimal('22.4984')),
#  ('Eastern Africa', 'Malawi', 2020, Decimal('19.377061'), Decimal('22.4984')),
#  ('Eastern Africa', 'Rwanda', 2020, Decimal('13.146362'), Decimal('22.4984')),
#  ('Eastern Africa', 'Zimbabwe', 2020, Decimal('15.669666'), Decimal('22.4984')),
#  ('Eastern Africa', 'Uganda', 2020, Decimal('44.404611'), Decimal('22.4984')),
#  ('Eastern Africa', 'Somalia', 2020, Decimal('16.537016'), Decimal('22.4984')),
#  ('Eastern Africa', 'Zambia', 2020, Decimal('18.927715'), Decimal('22.4984')),
#  ('Eastern Africa', 'South Sudan', 2020, Decimal('10.606227'), Decimal('22.4984')),
#  ('Eastern Africa', 'Burundi', 2020, Decimal('12.220227'), Decimal('22.4984')),
#  ('Eastern Asia', 'Japan', 2015, Decimal('127.141000'), Decimal('503.3219')),
#  ('Eastern Asia', 'China', 2015, Decimal('1379.860000'), Decimal('503.3219')),
#  ('Eastern Asia', 'Mongolia', 2015, Decimal('2.964749'), Decimal('503.3219')),
#  ('Eastern Asia', 'Mongolia', 2016, Decimal('3.029555'), Decimal('504.6436')),
#  ('Eastern Asia', 'China', 2016, Decimal('1387.790000'), Decimal('504.6436')),
#  ('Eastern Asia', 'Japan', 2016, Decimal('127.076000'), Decimal('504.6436')),
#  ('Eastern Asia', 'Mongolia', 2017, Decimal('3.096030'), Decimal('506.0160')),
#  ('Eastern Asia', 'China', 2017, Decimal('1396.215000'), Decimal('506.0160')),
#  ('Eastern Asia', 'Japan', 2017, Decimal('126.972000'), Decimal('506.0160')),
#  ('Eastern Asia', 'China', 2018, Decimal('1402.760000'), Decimal('507.2399')),
#  ('Eastern Asia', 'Japan', 2018, Decimal('126.811000'), Decimal('507.2399')),
#  ('Eastern Asia', 'Mongolia', 2018, Decimal('3.163991'), Decimal('507.2399')),
#  ('Eastern Asia', 'China', 2019, Decimal('1407.745000'), Decimal('508.2993')),
#  ('Eastern Asia', 'Japan', 2019, Decimal('126.633000'), Decimal('508.2993')),
#  ('Eastern Asia', 'Mongolia', 2019, Decimal('3.232430'), Decimal('508.2993')),
#  ('Eastern Asia', 'China', 2020, Decimal('1411.100000'), Decimal('509.1747')),
#  ('Eastern Asia', 'Japan', 2020, Decimal('126.261000'), Decimal('509.1747')),
#  ('Eastern Asia', 'Mongolia', 2020, Decimal('3.294335'), Decimal('509.1747')),
#  ('Melanesia', 'Solomon Islands', 2015, Decimal('0.612660'), Decimal('2.1516')),
#  ('Melanesia', 'Papua New Guinea', 2015, Decimal('8.682174'), Decimal('2.1516')),
#  ('Melanesia', 'Vanuatu', 2015, Decimal('0.276438'), Decimal('2.1516')),
#  ('Melanesia', 'Fiji', 2015, Decimal('0.917200'), Decimal('2.1516')),
#  ('Melanesia', 'New Caledonia', 2015, Decimal('0.269460'), Decimal('2.1516')),
#  ('Melanesia', 'New Caledonia', 2016, Decimal('0.270220'), Decimal('2.1757')),
#  ('Melanesia', 'Solomon Islands', 2016, Decimal('0.628102'), Decimal('2.1757')),
#  ('Melanesia', 'Papua New Guinea', 2016, Decimal('8.899169'), Decimal('2.1757')),
#  ('Melanesia', 'Fiji', 2016, Decimal('0.918371'), Decimal('2.1757')),
#  ('Melanesia', 'Vanuatu', 2016, Decimal('0.283218'), Decimal('2.1757')),
#  ('Melanesia', 'New Caledonia', 2017, Decimal('0.270810'), Decimal('2.1997')),
#  ('Melanesia', 'Solomon Islands', 2017, Decimal('0.643634'), Decimal('2.1997')),
#  ('Melanesia', 'Papua New Guinea', 2017, Decimal('9.114796'), Decimal('2.1997')),
#  ('Melanesia', 'Vanuatu', 2017, Decimal('0.290239'), Decimal('2.1997')),
#  ('Melanesia', 'Fiji', 2017, Decimal('0.919019'), Decimal('2.1997')),
#  ('Melanesia', 'New Caledonia', 2018, Decimal('0.271170'), Decimal('2.2236')),
#  ('Melanesia', 'Papua New Guinea', 2018, Decimal('9.329227'), Decimal('2.2236')),
#  ('Melanesia', 'Solomon Islands', 2018, Decimal('0.659249'), Decimal('2.2236')),
#  ('Melanesia', 'Fiji', 2018, Decimal('0.918996'), Decimal('2.2236')),
#  ('Melanesia', 'Vanuatu', 2018, Decimal('0.297298'), Decimal('2.2236')),
#  ('Melanesia', 'Fiji', 2019, Decimal('0.918465'), Decimal('2.2473')),
#  ('Melanesia', 'New Caledonia', 2019, Decimal('0.271230'), Decimal('2.2473')),
#  ('Melanesia', 'Vanuatu', 2019, Decimal('0.304404'), Decimal('2.2473')),
#  ('Melanesia', 'Papua New Guinea', 2019, Decimal('9.542486'), Decimal('2.2473')),
#  ('Melanesia', 'Solomon Islands', 2019, Decimal('0.674993'), Decimal('2.2473')),
#  ('Melanesia', 'Fiji', 2020, Decimal('0.920422'), Decimal('2.2709')),
#  ('Melanesia', 'Solomon Islands', 2020, Decimal('0.691191'), Decimal('2.2709')),
#  ('Melanesia', 'New Caledonia', 2020, Decimal('0.271130'), Decimal('2.2709')),
#  ('Melanesia', 'Vanuatu', 2020, Decimal('0.311685'), Decimal('2.2709')),
#  ('Melanesia', 'Papua New Guinea', 2020, Decimal('9.749640'), Decimal('2.2709')),
#  ('Micronesia', 'Guam', 2015, Decimal('0.167978'), Decimal('0.0691')),
#  ('Micronesia', 'Palau', 2015, Decimal('0.017794'), Decimal('0.0691')),
#  ('Micronesia', 'Marshall Islands', 2015, Decimal('0.049410'), Decimal('0.0691')),
#  ('Micronesia', 'Kiribati', 2015, Decimal('0.116707'), Decimal('0.0691')),
#  ('Micronesia', 'Northern Mariana Islands', 2015, Decimal('0.051514'), Decimal('0.0691')),
#  ('Micronesia', 'Nauru', 2015, Decimal('0.011185'), Decimal('0.0691')),
#  ('Micronesia', 'Marshall Islands', 2016, Decimal('0.048329'), Decimal('0.0692')),
#  ('Micronesia', 'Kiribati', 2016, Decimal('0.118513'), Decimal('0.0692')),
#  ('Micronesia', 'Nauru', 2016, Decimal('0.011437'), Decimal('0.0692')),
#  ('Micronesia', 'Northern Mariana Islands', 2016, Decimal('0.051133'), Decimal('0.0692')),
#  ('Micronesia', 'Guam', 2016, Decimal('0.168346'), Decimal('0.0692')),
#  ('Micronesia', 'Palau', 2016, Decimal('0.017816'), Decimal('0.0692')),
#  ('Micronesia', 'Marshall Islands', 2017, Decimal('0.047187'), Decimal('0.0693')),
#  ('Micronesia', 'Guam', 2017, Decimal('0.168606'), Decimal('0.0693')),
#  ('Micronesia', 'Palau', 2017, Decimal('0.017837'), Decimal('0.0693')),
#  ('Micronesia', 'Kiribati', 2017, Decimal('0.120362'), Decimal('0.0693')),
#  ('Micronesia', 'Nauru', 2017, Decimal('0.011682'), Decimal('0.0693')),
#  ('Micronesia', 'Northern Mariana Islands', 2017, Decimal('0.050729'), Decimal('0.0693')),
#  ('Micronesia', 'Guam', 2018, Decimal('0.168678'), Decimal('0.0693')),
#  ('Micronesia', 'Kiribati', 2018, Decimal('0.122261'), Decimal('0.0693')),
#  ('Micronesia', 'Marshall Islands', 2018, Decimal('0.045989'), Decimal('0.0693')),
#  ('Micronesia', 'Palau', 2018, Decimal('0.017864'), Decimal('0.0693')),
#  ('Micronesia', 'Nauru', 2018, Decimal('0.011924'), Decimal('0.0693')),
#  ('Micronesia', 'Northern Mariana Islands', 2018, Decimal('0.050304'), Decimal('0.0693')),
#  ('Micronesia', 'Kiribati', 2019, Decimal('0.124241'), Decimal('0.0694')),
#  ('Micronesia', 'Marshall Islands', 2019, Decimal('0.044728'), Decimal('0.0694')),
#  ('Micronesia', 'Palau', 2019, Decimal('0.017916'), Decimal('0.0694')),
#  ('Micronesia', 'Nauru', 2019, Decimal('0.012132'), Decimal('0.0694')),
#  ('Micronesia', 'Northern Mariana Islands', 2019, Decimal('0.049858'), Decimal('0.0694')),
#  ('Micronesia', 'Guam', 2019, Decimal('0.168624'), Decimal('0.0694')),
#  ('Micronesia', 'Kiribati', 2020, Decimal('0.126463'), Decimal('0.0694')),
#  ('Micronesia', 'Guam', 2020, Decimal('0.169231'), Decimal('0.0694')),
#  ('Micronesia', 'Marshall Islands', 2020, Decimal('0.043413'), Decimal('0.0694')),
#  ('Micronesia', 'Nauru', 2020, Decimal('0.012315'), Decimal('0.0694')),
#  ('Micronesia', 'Palau', 2020, Decimal('0.017972'), Decimal('0.0694')),
#  ('Micronesia', 'Northern Mariana Islands', 2020, Decimal('0.049587'), Decimal('0.0694')),
#  ('Middle Africa', 'Chad', 2015, Decimal('14.140274'), Decimal('10.5252')),
#  ('Middle Africa', 'Angola', 2015, Decimal('28.127721'), Decimal('10.5252')),
#  ('Middle Africa', 'Equatorial Guinea', 2015, Decimal('1.346973'), Decimal('10.5252')),
#  ('Middle Africa', 'Gabon', 2015, Decimal('2.028517'), Decimal('10.5252')),
#  ('Middle Africa', 'Cameroon', 2015, Decimal('23.012646'), Decimal('10.5252')),
#  ('Middle Africa', 'Central African Republic', 2015, Decimal('4.819333'), Decimal('10.5252')),
#  ('Middle Africa', 'Sao Tome and Principe', 2015, Decimal('0.201124'), Decimal('10.5252')),
#  ('Middle Africa', 'Chad', 2016, Decimal('14.592585'), Decimal('10.6950')),
#  ('Middle Africa', 'Angola', 2016, Decimal('29.154746'), Decimal('10.6950')),
#  ('Middle Africa', 'Equatorial Guinea', 2016, Decimal('1.398927'), Decimal('10.6950')),
#  ('Middle Africa', 'Central African Republic', 2016, Decimal('4.904177'), Decimal('10.6950')),
#  ('Middle Africa', 'Cameroon', 2016, Decimal('23.711630'), Decimal('10.6950')),
#  ('Middle Africa', 'Gabon', 2016, Decimal('2.086206'), Decimal('10.6950')),
#  ('Middle Africa', 'Sao Tome and Principe', 2016, Decimal('0.204632'), Decimal('10.6950')),
#  ('Middle Africa', 'Angola', 2017, Decimal('30.208628'), Decimal('10.8673')),
#  ('Middle Africa', 'Central African Republic', 2017, Decimal('4.996741'), Decimal('10.8673')),
#  ('Middle Africa', 'Chad', 2017, Decimal('15.085884'), Decimal('10.8673')),
#  ('Middle Africa', 'Cameroon', 2017, Decimal('24.393181'), Decimal('10.8673')),
#  ('Middle Africa', 'Gabon', 2017, Decimal('2.140215'), Decimal('10.8673')),
#  ('Middle Africa', 'Sao Tome and Principe', 2017, Decimal('0.208036'), Decimal('10.8673')),
#  ('Middle Africa', 'Equatorial Guinea', 2017, Decimal('1.450694'), Decimal('10.8673')),
#  ('Middle Africa', 'Cameroon', 2018, Decimal('25.076747'), Decimal('11.3950')),
#  ('Middle Africa', 'Angola', 2018, Decimal('31.273533'), Decimal('11.3950')),
#  ('Middle Africa', 'Central African Republic', 2018, Decimal('5.094780'), Decimal('11.3950')),
#  ('Middle Africa', 'Chad', 2018, Decimal('15.604210'), Decimal('11.3950')),
#  ('Middle Africa', 'Gabon', 2018, Decimal('2.192012'), Decimal('11.3950')),
#  ('Middle Africa', 'Sao Tome and Principe', 2018, Decimal('0.211344'), Decimal('11.3950')),
#  ('Middle Africa', 'Central African Republic', 2019, Decimal('5.209324'), Decimal('11.8059')),
#  ('Middle Africa', 'Gabon', 2019, Decimal('2.242785'), Decimal('11.8059')),
#  ('Middle Africa', 'Angola', 2019, Decimal('32.353588'), Decimal('11.8059')),
#  ('Middle Africa', 'Chad', 2019, Decimal('16.126866'), Decimal('11.8059')),
#  ('Middle Africa', 'Cameroon', 2019, Decimal('25.782341'), Decimal('11.8059')),
#  ('Middle Africa', 'Sao Tome and Principe', 2019, Decimal('0.214599'), Decimal('11.8059')),
#  ('Middle Africa', 'Gabon', 2020, Decimal('2.292573'), Decimal('12.1542')),
#  ('Middle Africa', 'Chad', 2020, Decimal('16.644701'), Decimal('12.1542')),
#  ('Middle Africa', 'Central African Republic', 2020, Decimal('5.343020'), Decimal('12.1542')),
#  ('Middle Africa', 'Angola', 2020, Decimal('33.428486'), Decimal('12.1542')),
#  ('Middle Africa', 'Sao Tome and Principe', 2020, Decimal('0.218641'), Decimal('12.1542')),
#  ('Middle Africa', 'Cameroon', 2020, Decimal('26.491087'), Decimal('12.1542')),
#  ('Northern Africa', 'Morocco', 2015, Decimal('34.680458'), Decimal('26.0290')),
#  ('Northern Africa', 'Algeria', 2015, Decimal('39.543154'), Decimal('26.0290')),
#  ('Northern Africa', 'Tunisia', 2015, Decimal('11.557779'), Decimal('26.0290')),
#  ('Northern Africa', 'Sudan', 2015, Decimal('38.171178'), Decimal('26.0290')),
#  ('Northern Africa', 'Libya', 2015, Decimal('6.192235'), Decimal('26.0290')),
#  ('Northern Africa', 'Algeria', 2016, Decimal('40.339329'), Decimal('26.2936')),
#  ('Northern Africa', 'Tunisia', 2016, Decimal('11.685667'), Decimal('26.2936')),
#  ('Northern Africa', 'Sudan', 2016, Decimal('39.377169'), Decimal('26.2936')),
#  ('Northern Africa', 'Morocco', 2016, Decimal('35.107264'), Decimal('26.2936')),
#  ('Northern Africa', 'Libya', 2016, Decimal('6.282196'), Decimal('26.2936')),
#  ('Northern Africa', 'Sudan', 2017, Decimal('40.679828'), Decimal('26.5647')),
#  ('Northern Africa', 'Algeria', 2017, Decimal('41.136546'), Decimal('26.5647')),
#  ('Northern Africa', 'Morocco', 2017, Decimal('35.528115'), Decimal('26.5647')),
#  ('Northern Africa', 'Libya', 2017, Decimal('6.378261'), Decimal('26.5647')),
#  ('Northern Africa', 'Tunisia', 2017, Decimal('11.811443'), Decimal('26.5647')),
#  ('Northern Africa', 'Tunisia', 2018, Decimal('11.933041'), Decimal('26.8368')),
#  ('Northern Africa', 'Sudan', 2018, Decimal('41.999059'), Decimal('26.8368')),
#  ('Northern Africa', 'Morocco', 2018, Decimal('35.927511'), Decimal('26.8368')),
#  ('Northern Africa', 'Algeria', 2018, Decimal('41.927007'), Decimal('26.8368')),
#  ('Northern Africa', 'Libya', 2018, Decimal('6.477793'), Decimal('26.8368')),
#  ('Northern Africa', 'Tunisia', 2019, Decimal('12.049314'), Decimal('27.1038')),
#  ('Northern Africa', 'Sudan', 2019, Decimal('43.232093'), Decimal('27.1038')),
#  ('Northern Africa', 'Algeria', 2019, Decimal('42.705368'), Decimal('27.1038')),
#  ('Northern Africa', 'Libya', 2019, Decimal('6.569088'), Decimal('27.1038')),
#  ('Northern Africa', 'Morocco', 2019, Decimal('36.304408'), Decimal('27.1038')),
#  ('Northern Africa', 'Tunisia', 2020, Decimal('12.161723'), Decimal('27.3664')),
#  ('Northern Africa', 'Algeria', 2020, Decimal('43.451666'), Decimal('27.3664')),
#  ('Northern Africa', 'Sudan', 2020, Decimal('44.440486'), Decimal('27.3664')),
#  ('Northern Africa', 'Morocco', 2020, Decimal('36.688772'), Decimal('27.3664')),
#  ('Northern Africa', 'Libya', 2020, Decimal('6.653942'), Decimal('27.3664')),
#  ('Northern America', 'Greenland', 2015, Decimal('0.056114'), Decimal('11.9414')),
#  ('Northern America', 'Canada', 2015, Decimal('35.702908'), Decimal('11.9414')),
#  ('Northern America', 'Bermuda', 2015, Decimal('0.065237'), Decimal('11.9414')),
#  ('Northern America', 'Greenland', 2016, Decimal('0.056186'), Decimal('12.0091')),
#  ('Northern America', 'Bermuda', 2016, Decimal('0.064554'), Decimal('12.0091')),
#  ('Northern America', 'Canada', 2016, Decimal('36.109487'), Decimal('12.0091')),
#  ('Northern America', 'Bermuda', 2017, Decimal('0.063873'), Decimal('12.0800')),
#  ('Northern America', 'Canada', 2017, Decimal('36.545236'), Decimal('12.0800')),
#  ('Northern America', 'Greenland', 2017, Decimal('0.056171'), Decimal('12.0800')),
#  ('Northern America', 'Greenland', 2018, Decimal('0.056023'), Decimal('12.1587')),
#  ('Northern America', 'Canada', 2018, Decimal('37.065084'), Decimal('12.1587')),
#  ('Northern America', 'Bermuda', 2018, Decimal('0.063918'), Decimal('12.1587')),
#  ('Northern America', 'Bermuda', 2019, Decimal('0.063911'), Decimal('12.2417')),
#  ('Northern America', 'Canada', 2019, Decimal('37.601230'), Decimal('12.2417')),
#  ('Northern America', 'Greenland', 2019, Decimal('0.056225'), Decimal('12.2417')),
#  ('Northern America', 'Bermuda', 2020, Decimal('0.063893'), Decimal('12.3213')),
#  ('Northern America', 'Greenland', 2020, Decimal('0.056367'), Decimal('12.3213')),
#  ('Northern America', 'Canada', 2020, Decimal('38.037204'), Decimal('12.3213')),
#  ('Polynesia', 'Samoa', 2015, Decimal('0.203571'), Decimal('0.1327')),
#  ('Polynesia', 'Tuvalu', 2015, Decimal('0.010877'), Decimal('0.1327')),
#  ('Polynesia', 'American Samoa', 2015, Decimal('0.051368'), Decimal('0.1327')),
#  ('Polynesia', 'French Polynesia', 2015, Decimal('0.291787'), Decimal('0.1327')),
#  ('Polynesia', 'Tonga', 2015, Decimal('0.106122'), Decimal('0.1327')),
#  ('Polynesia', 'Samoa', 2016, Decimal('0.205544'), Decimal('0.1330')),
#  ('Polynesia', 'Tuvalu', 2016, Decimal('0.010852'), Decimal('0.1330')),
#  ('Polynesia', 'French Polynesia', 2016, Decimal('0.293541'), Decimal('0.1330')),
#  ('Polynesia', 'American Samoa', 2016, Decimal('0.050448'), Decimal('0.1330')),
#  ('Polynesia', 'Tonga', 2016, Decimal('0.105707'), Decimal('0.1330')),
#  ('Polynesia', 'Samoa', 2017, Decimal('0.207630'), Decimal('0.1332')),
#  ('Polynesia', 'Tuvalu', 2017, Decimal('0.010828'), Decimal('0.1332')),
#  ('Polynesia', 'French Polynesia', 2017, Decimal('0.295450'), Decimal('0.1332')),
#  ('Polynesia', 'American Samoa', 2017, Decimal('0.049463'), Decimal('0.1332')),
#  ('Polynesia', 'Tonga', 2017, Decimal('0.105415'), Decimal('0.1332')),
#  ('Polynesia', 'Samoa', 2018, Decimal('0.209701'), Decimal('0.1335')),
#  ('Polynesia', 'Tuvalu', 2018, Decimal('0.010865'), Decimal('0.1335')),
#  ('Polynesia', 'Tonga', 2018, Decimal('0.105150'), Decimal('0.1335')),
#  ('Polynesia', 'French Polynesia', 2018, Decimal('0.297606'), Decimal('0.1335')),
#  ('Polynesia', 'American Samoa', 2018, Decimal('0.048424'), Decimal('0.1335')),
#  ('Polynesia', 'Tonga', 2019, Decimal('0.104951'), Decimal('0.1338')),
#  ('Polynesia', 'Samoa', 2019, Decimal('0.211905'), Decimal('0.1338')),
#  ('Polynesia', 'French Polynesia', 2019, Decimal('0.299717'), Decimal('0.1338')),
#  ('Polynesia', 'Tuvalu', 2019, Decimal('0.010956'), Decimal('0.1338')),
#  ('Polynesia', 'American Samoa', 2019, Decimal('0.047321'), Decimal('0.1338')),
#  ('Polynesia', 'Tuvalu', 2020, Decimal('0.011069'), Decimal('0.1342')),
#  ('Polynesia', 'French Polynesia', 2020, Decimal('0.301920'), Decimal('0.1342')),
#  ('Polynesia', 'Samoa', 2020, Decimal('0.214929'), Decimal('0.1342')),
#  ('Polynesia', 'Tonga', 2020, Decimal('0.105254'), Decimal('0.1342')),
#  ('Polynesia', 'American Samoa', 2020, Decimal('0.046189'), Decimal('0.1342')),
#  ('South America', 'Paraguay', 2015, Decimal('6.177950'), Decimal('37.1129')),
#  ('South America', 'Argentina', 2015, Decimal('43.131966'), Decimal('37.1129')),
#  ('South America', 'Chile', 2015, Decimal('17.870124'), Decimal('37.1129')),
#  ('South America', 'Ecuador', 2015, Decimal('16.195902'), Decimal('37.1129')),
#  ('South America', 'Suriname', 2015, Decimal('0.575475'), Decimal('37.1129')),
#  ('South America', 'Uruguay', 2015, Decimal('3.402818'), Decimal('37.1129')),
#  ('South America', 'Peru', 2015, Decimal('30.711863'), Decimal('37.1129')),
#  ('South America', 'Brazil', 2015, Decimal('205.188205'), Decimal('37.1129')),
#  ('South America', 'Guyana', 2015, Decimal('0.755031'), Decimal('37.1129')),
#  ('South America', 'Colombia', 2015, Decimal('47.119728'), Decimal('37.1129')),
#  ('South America', 'Argentina', 2016, Decimal('43.590368'), Decimal('37.2941')),
#  ('South America', 'Brazil', 2016, Decimal('206.859578'), Decimal('37.2941')),
#  ('South America', 'Ecuador', 2016, Decimal('16.439585'), Decimal('37.2941')),
#  ('South America', 'Uruguay', 2016, Decimal('3.413766'), Decimal('37.2941')),
#  ('South America', 'Suriname', 2016, Decimal('0.581453'), Decimal('37.2941')),
#  ('South America', 'Paraguay', 2016, Decimal('6.266615'), Decimal('37.2941')),
#  ('South America', 'Peru', 2016, Decimal('31.132779'), Decimal('37.2941')),
#  ('South America', 'Colombia', 2016, Decimal('47.625955'), Decimal('37.2941')),
#  ('South America', 'Chile', 2016, Decimal('18.083879'), Decimal('37.2941')),
#  ('South America', 'Guyana', 2016, Decimal('0.759087'), Decimal('37.2941')),
#  ('South America', 'Brazil', 2017, Decimal('208.504960'), Decimal('37.4861')),
#  ('South America', 'Paraguay', 2017, Decimal('6.355404'), Decimal('37.4861')),
#  ('South America', 'Colombia', 2017, Decimal('48.351671'), Decimal('37.4861')),
#  ('South America', 'Peru', 2017, Decimal('31.605486'), Decimal('37.4861')),
#  ('South America', 'Guyana', 2017, Decimal('0.763252'), Decimal('37.4861')),
#  ('South America', 'Suriname', 2017, Decimal('0.587559'), Decimal('37.4861')),
#  ('South America', 'Argentina', 2017, Decimal('44.044811'), Decimal('37.4861')),
#  ('South America', 'Chile', 2017, Decimal('18.368577'), Decimal('37.4861')),
#  ('South America', 'Ecuador', 2017, Decimal('16.696944'), Decimal('37.4861')),
#  ('South America', 'Uruguay', 2017, Decimal('3.422200'), Decimal('37.4861')),
#  ('South America', 'Peru', 2018, Decimal('32.203944'), Decimal('37.6923')),
#  ('South America', 'Ecuador', 2018, Decimal('17.015672'), Decimal('37.6923')),
#  ('South America', 'Guyana', 2018, Decimal('0.785514'), Decimal('37.6923')),
#  ('South America', 'Argentina', 2018, Decimal('44.494502'), Decimal('37.6923')),
#  ('South America', 'Brazil', 2018, Decimal('210.166592'), Decimal('37.6923')),
#  ('South America', 'Paraguay', 2018, Decimal('6.443328'), Decimal('37.6923')),
#  ('South America', 'Chile', 2018, Decimal('18.701450'), Decimal('37.6923')),
#  ('South America', 'Suriname', 2018, Decimal('0.593715'), Decimal('37.6923')),
#  ('South America', 'Colombia', 2018, Decimal('49.276961'), Decimal('37.6923')),
#  ('South America', 'Uruguay', 2018, Decimal('3.427042'), Decimal('37.6923')),
#  ('South America', 'Brazil', 2019, Decimal('211.782878'), Decimal('37.9033')),
#  ('South America', 'Chile', 2019, Decimal('19.039485'), Decimal('37.9033')),
#  ('South America', 'Colombia', 2019, Decimal('50.187406'), Decimal('37.9033')),
#  ('South America', 'Guyana', 2019, Decimal('0.798753'), Decimal('37.9033')),
#  ('South America', 'Paraguay', 2019, Decimal('6.530026'), Decimal('37.9033')),
#  ('South America', 'Peru', 2019, Decimal('32.824861'), Decimal('37.9033')),
#  ('South America', 'Suriname', 2019, Decimal('0.600301'), Decimal('37.9033')),
#  ('South America', 'Uruguay', 2019, Decimal('3.428409'), Decimal('37.9033')),
#  ('South America', 'Ecuador', 2019, Decimal('17.343740'), Decimal('37.9033')),
#  ('South America', 'Argentina', 2019, Decimal('44.938712'), Decimal('37.9033')),
#  ('South America', 'Peru', 2020, Decimal('33.304756'), Decimal('38.1053')),
#  ('South America', 'Paraguay', 2020, Decimal('6.618695'), Decimal('38.1053')),
#  ('South America', 'Guyana', 2020, Decimal('0.797202'), Decimal('38.1053')),
#  ('South America', 'Ecuador', 2020, Decimal('17.588595'), Decimal('38.1053')),
#  ('South America', 'Colombia', 2020, Decimal('50.930662'), Decimal('38.1053')),
#  ('South America', 'Chile', 2020, Decimal('19.300315'), Decimal('38.1053')),
#  ('South America', 'Brazil', 2020, Decimal('213.196304'), Decimal('38.1053')),
#  ('South America', 'Argentina', 2020, Decimal('45.376763'), Decimal('38.1053')),
#  ('South America', 'Uruguay', 2020, Decimal('3.429086'), Decimal('38.1053')),
#  ('South America', 'Suriname', 2020, Decimal('0.607065'), Decimal('38.1053')),
#  ('South-Eastern Asia', 'Myanmar', 2015, Decimal('51.483949'), Decimal('59.7278')),
#  ('South-Eastern Asia', 'Cambodia', 2015, Decimal('15.417523'), Decimal('59.7278')),
#  ('South-Eastern Asia', 'Indonesia', 2015, Decimal('259.091970'), Decimal('59.7278')),
#  ('South-Eastern Asia', 'Brunei Darussalam', 2015, Decimal('0.421437'), Decimal('59.7278')),
#  ('South-Eastern Asia', 'Thailand', 2015, Decimal('70.294397'), Decimal('59.7278')),
#  ('South-Eastern Asia', 'Malaysia', 2015, Decimal('31.068833'), Decimal('59.7278')),
#  ('South-Eastern Asia', 'Singapore', 2015, Decimal('5.535002'), Decimal('59.7278')),
#  ('South-Eastern Asia', 'Timor-Leste', 2015, Decimal('1.205813'), Decimal('59.7278')),
#  ('South-Eastern Asia', 'Philippines', 2015, Decimal('103.031365'), Decimal('59.7278')),
#  ('South-Eastern Asia', 'Cambodia', 2016, Decimal('15.624584'), Decimal('60.0658')),
#  ('South-Eastern Asia', 'Timor-Leste', 2016, Decimal('1.224562'), Decimal('60.0658')),
#  ('South-Eastern Asia', 'Malaysia', 2016, Decimal('31.526418'), Decimal('60.0658')),
#  ('South-Eastern Asia', 'Philippines', 2016, Decimal('104.875266'), Decimal('60.0658')),
#  ('South-Eastern Asia', 'Indonesia', 2016, Decimal('261.850182'), Decimal('60.0658')),
#  ('South-Eastern Asia', 'Myanmar', 2016, Decimal('51.892349'), Decimal('60.0658')),
#  ('South-Eastern Asia', 'Singapore', 2016, Decimal('5.607283'), Decimal('60.0658')),
#  ('South-Eastern Asia', 'Brunei Darussalam', 2016, Decimal('0.425994'), Decimal('60.0658')),
#  ('South-Eastern Asia', 'Thailand', 2016, Decimal('70.607037'), Decimal('60.0658')),
#  ('South-Eastern Asia', 'Timor-Leste', 2017, Decimal('1.243235'), Decimal('60.3963')),
#  ('South-Eastern Asia', 'Cambodia', 2017, Decimal('15.830689'), Decimal('60.3963')),
#  ('South-Eastern Asia', 'Thailand', 2017, Decimal('70.898202'), Decimal('60.3963')),
#  ('South-Eastern Asia', 'Philippines', 2017, Decimal('106.738501'), Decimal('60.3963')),
#  ('South-Eastern Asia', 'Singapore', 2017, Decimal('5.612253'), Decimal('60.3963')),
#  ('South-Eastern Asia', 'Myanmar', 2017, Decimal('52.288341'), Decimal('60.3963')),
#  ('South-Eastern Asia', 'Malaysia', 2017, Decimal('31.975806'), Decimal('60.3963')),
#  ('South-Eastern Asia', 'Brunei Darussalam', 2017, Decimal('0.430276'), Decimal('60.3963')),
#  ('South-Eastern Asia', 'Indonesia', 2017, Decimal('264.498852'), Decimal('60.3963')),
#  ('South-Eastern Asia', 'Brunei Darussalam', 2018, Decimal('0.434274'), Decimal('60.7191')),
#  ('South-Eastern Asia', 'Indonesia', 2018, Decimal('267.066843'), Decimal('60.7191')),
#  ('South-Eastern Asia', 'Timor-Leste', 2018, Decimal('1.261845'), Decimal('60.7191')),
#  ('South-Eastern Asia', 'Malaysia', 2018, Decimal('32.399271'), Decimal('60.7191')),
#  ('South-Eastern Asia', 'Thailand', 2018, Decimal('71.127802'), Decimal('60.7191')),
#  ('South-Eastern Asia', 'Philippines', 2018, Decimal('108.568836'), Decimal('60.7191')),
#  ('South-Eastern Asia', 'Cambodia', 2018, Decimal('16.025238'), Decimal('60.7191')),
#  ('South-Eastern Asia', 'Myanmar', 2018, Decimal('52.666014'), Decimal('60.7191')),
#  ('South-Eastern Asia', 'Singapore', 2018, Decimal('5.638676'), Decimal('60.7191')),
#  ('South-Eastern Asia', 'Malaysia', 2019, Decimal('32.804020'), Decimal('61.0363')),
#  ('South-Eastern Asia', 'Indonesia', 2019, Decimal('269.582878'), Decimal('61.0363')),
#  ('South-Eastern Asia', 'Cambodia', 2019, Decimal('16.207746'), Decimal('61.0363')),
#  ('South-Eastern Asia', 'Brunei Darussalam', 2019, Decimal('0.438048'), Decimal('61.0363')),
#  ('South-Eastern Asia', 'Timor-Leste', 2019, Decimal('1.280438'), Decimal('61.0363')),
#  ('South-Eastern Asia', 'Thailand', 2019, Decimal('71.307763'), Decimal('61.0363')),
#  ('South-Eastern Asia', 'Singapore', 2019, Decimal('5.703569'), Decimal('61.0363')),
#  ('South-Eastern Asia', 'Philippines', 2019, Decimal('110.380804'), Decimal('61.0363')),
#  ('South-Eastern Asia', 'Myanmar', 2019, Decimal('53.040212'), Decimal('61.0363')),
#  ('South-Eastern Asia', 'Timor-Leste', 2020, Decimal('1.299995'), Decimal('61.3446')),
#  ('South-Eastern Asia', 'Brunei Darussalam', 2020, Decimal('0.441725'), Decimal('61.3446')),
#  ('South-Eastern Asia', 'Malaysia', 2020, Decimal('33.199993'), Decimal('61.3446')),
#  ('South-Eastern Asia', 'Cambodia', 2020, Decimal('16.396860'), Decimal('61.3446')),
#  ('South-Eastern Asia', 'Myanmar', 2020, Decimal('53.423198'), Decimal('61.3446')),
#  ('South-Eastern Asia', 'Philippines', 2020, Decimal('112.190977'), Decimal('61.3446')),
#  ('South-Eastern Asia', 'Indonesia', 2020, Decimal('271.857970'), Decimal('61.3446')),
#  ('South-Eastern Asia', 'Singapore', 2020, Decimal('5.685807'), Decimal('61.3446')),
#  ('South-Eastern Asia', 'Thailand', 2020, Decimal('71.475664'), Decimal('61.3446')),
#  ('Southern Africa', 'Namibia', 2015, Decimal('2.282704'), Decimal('12.7434')),
#  ('Southern Africa', 'Eswatini', 2015, Decimal('1.133936'), Decimal('12.7434')),
#  ('Southern Africa', 'South Africa', 2015, Decimal('55.876504'), Decimal('12.7434')),
#  ('Southern Africa', 'Botswana', 2015, Decimal('2.305171'), Decimal('12.7434')),
#  ('Southern Africa', 'Lesotho', 2015, Decimal('2.118521'), Decimal('12.7434')),
#  ('Southern Africa', 'Namibia', 2016, Decimal('2.323352'), Decimal('12.8101')),
#  ('Southern Africa', 'Botswana', 2016, Decimal('2.352416'), Decimal('12.8101')),
#  ('Southern Africa', 'Eswatini', 2016, Decimal('1.142524'), Decimal('12.8101')),
#  ('Southern Africa', 'South Africa', 2016, Decimal('56.422274'), Decimal('12.8101')),
#  ('Southern Africa', 'Lesotho', 2016, Decimal('2.143872'), Decimal('12.8101')),
#  ('Southern Africa', 'South Africa', 2017, Decimal('56.641209'), Decimal('12.8554')),
#  ('Southern Africa', 'Eswatini', 2017, Decimal('1.151390'), Decimal('12.8554')),
#  ('Southern Africa', 'Namibia', 2017, Decimal('2.364534'), Decimal('12.8554')),
#  ('Southern Africa', 'Botswana', 2017, Decimal('2.401840'), Decimal('12.8554')),
#  ('Southern Africa', 'Lesotho', 2017, Decimal('2.170617'), Decimal('12.8554')),
#  ('Southern Africa', 'Botswana', 2018, Decimal('2.451409'), Decimal('12.9193')),
#  ('Southern Africa', 'Namibia', 2018, Decimal('2.405680'), Decimal('12.9193')),
#  ('Southern Africa', 'South Africa', 2018, Decimal('57.339635'), Decimal('12.9193')),
#  ('Southern Africa', 'Lesotho', 2018, Decimal('2.198017'), Decimal('12.9193')),
#  ('Southern Africa', 'Eswatini', 2018, Decimal('1.160428'), Decimal('12.9193')),
#  ('Southern Africa', 'Namibia', 2019, Decimal('2.446644'), Decimal('12.9926')),
#  ('Southern Africa', 'Eswatini', 2019, Decimal('1.169613'), Decimal('12.9926')),
#  ('Southern Africa', 'Botswana', 2019, Decimal('2.499702'), Decimal('12.9926')),
#  ('Southern Africa', 'Lesotho', 2019, Decimal('2.225702'), Decimal('12.9926')),
#  ('Southern Africa', 'South Africa', 2019, Decimal('58.087055'), Decimal('12.9926')),
#  ('Southern Africa', 'Namibia', 2020, Decimal('2.489098'), Decimal('13.0696')),
#  ('Southern Africa', 'Eswatini', 2020, Decimal('1.180655'), Decimal('13.0696')),
#  ('Southern Africa', 'Botswana', 2020, Decimal('2.546402'), Decimal('13.0696')),
#  ('Southern Africa', 'South Africa', 2020, Decimal('58.801927'), Decimal('13.0696')),
#  ('Southern Africa', 'Lesotho', 2020, Decimal('2.254100'), Decimal('13.0696')),
#  ('Southern Asia', 'Maldives', 2015, Decimal('0.435582'), Decimal('221.8973')),
# ...
#  ('Southern Asia', 'Bhutan', 2017, Decimal('0.756121'), Decimal('224.6207')),
#  ('Southern Asia', 'Maldives', 2017, Decimal('0.472442'), Decimal('224.6207')),
#  ('Southern Asia', 'Nepal', 2018, Decimal('28.506712'), Decimal('225.9822')),
#  ('Southern Asia', 'Sri Lanka', 2018, Decimal('21.670000'), Decimal('225.9822')),
#  ('Southern Asia', 'Afghanistan', 2018, Decimal('36.686784'), Decimal('225.9822')),
#  ('Southern Asia', 'Bangladesh', 2018, Decimal('163.683958'), Decimal('225.9822')),
#  ('Southern Asia', 'Pakistan', 2018, Decimal('219.731479'), Decimal('225.9822')),
#  ('Southern Asia', 'India', 2018, Decimal('1369.003306'), Decimal('225.9822')),
#  ('Southern Asia', 'Bhutan', 2018, Decimal('0.762096'), Decimal('225.9822')),
#  ('Southern Asia', 'Maldives', 2018, Decimal('0.489758'), Decimal('225.9822')),
#  ('Southern Asia', 'Bhutan', 2019, Decimal('0.767459'), Decimal('227.3257')),
#  ('Southern Asia', 'Sri Lanka', 2019, Decimal('21.803000'), Decimal('227.3257')),
#  ('Southern Asia', 'India', 2019, Decimal('1383.112050'), Decimal('227.3257')),
#  ('Southern Asia', 'Pakistan', 2019, Decimal('223.293280'), Decimal('227.3257')),
#  ('Southern Asia', 'Maldives', 2019, Decimal('0.504508'), Decimal('227.3257')),
#  ('Southern Asia', 'Nepal', 2019, Decimal('28.832496'), Decimal('227.3257')),
#  ('Southern Asia', 'Bangladesh', 2019, Decimal('165.516222'), Decimal('227.3257')),
#  ('Southern Asia', 'Afghanistan', 2019, Decimal('37.769499'), Decimal('227.3257')),
#  ('Southern Asia', 'Sri Lanka', 2020, Decimal('21.919000'), Decimal('228.6575')),
#  ('Southern Asia', 'Pakistan', 2020, Decimal('227.196741'), Decimal('228.6575')),
#  ('Southern Asia', 'India', 2020, Decimal('1396.387127'), Decimal('228.6575')),
#  ('Southern Asia', 'Maldives', 2020, Decimal('0.514438'), Decimal('228.6575')),
#  ('Southern Asia', 'Bangladesh', 2020, Decimal('167.420951'), Decimal('228.6575')),
#  ('Southern Asia', 'Afghanistan', 2020, Decimal('38.972230'), Decimal('228.6575')),
#  ('Southern Asia', 'Bhutan', 2020, Decimal('0.772506'), Decimal('228.6575')),
#  ('Southern Asia', 'Nepal', 2020, Decimal('29.348627'), Decimal('228.6575')),
#  ('Western Africa', 'Nigeria', 2015, Decimal('183.995785'), Decimal('23.7449')),
#  ('Western Africa', 'Cabo Verde', 2015, Decimal('0.552166'), Decimal('23.7449')),
#  ('Western Africa', 'Senegal', 2015, Decimal('14.356181'), Decimal('23.7449')),
#  ('Western Africa', 'Guinea', 2015, Decimal('11.625998'), Decimal('23.7449')),
#  ('Western Africa', 'Niger', 2015, Decimal('20.128124'), Decimal('23.7449')),
#  ('Western Africa', 'Guinea-Bissau', 2015, Decimal('1.788919'), Decimal('23.7449')),
#  ('Western Africa', 'Mauritania', 2015, Decimal('3.946220'), Decimal('23.7449')),
#  ('Western Africa', 'Mali', 2015, Decimal('18.112907'), Decimal('23.7449')),
#  ('Western Africa', 'Liberia', 2015, Decimal('4.612329'), Decimal('23.7449')),
#  ('Western Africa', 'Burkina Faso', 2015, Decimal('18.718019'), Decimal('23.7449')),
#  ('Western Africa', 'Ghana', 2015, Decimal('28.870939'), Decimal('23.7449')),
#  ('Western Africa', 'Benin', 2015, Decimal('10.932783'), Decimal('23.7449')),
#  ('Western Africa', 'Sierra Leone', 2015, Decimal('7.314773'), Decimal('23.7449')),
#  ('Western Africa', 'Togo', 2015, Decimal('7.473229'), Decimal('23.7449')),
#  ('Western Africa', 'Ghana', 2016, Decimal('29.554303'), Decimal('24.0641')),
#  ('Western Africa', 'Benin', 2016, Decimal('11.260085'), Decimal('24.0641')),
#  ('Western Africa', 'Guinea', 2016, Decimal('11.930985'), Decimal('24.0641')),
#  ('Western Africa', 'Guinea-Bissau', 2016, Decimal('1.834552'), Decimal('24.0641')),
#  ('Western Africa', 'Liberia', 2016, Decimal('4.706097'), Decimal('24.0641')),
#  ('Western Africa', 'Mali', 2016, Decimal('18.700106'), Decimal('24.0641')),
#  ('Western Africa', 'Mauritania', 2016, Decimal('4.051890'), Decimal('24.0641')),
#  ('Western Africa', 'Senegal', 2016, Decimal('14.751356'), Decimal('24.0641')),
#  ('Western Africa', 'Niger', 2016, Decimal('20.921743'), Decimal('24.0641')),
#  ('Western Africa', 'Nigeria', 2016, Decimal('188.666931'), Decimal('24.0641')),
#  ('Western Africa', 'Cabo Verde', 2016, Decimal('0.558394'), Decimal('24.0641')),
#  ('Western Africa', 'Sierra Leone', 2016, Decimal('7.493913'), Decimal('24.0641')),
#  ('Western Africa', 'Burkina Faso', 2016, Decimal('19.275498'), Decimal('24.0641')),
#  ('Western Africa', 'Togo', 2016, Decimal('7.661354'), Decimal('24.0641')),
#  ('Western Africa', 'Mali', 2017, Decimal('19.311355'), Decimal('24.3887')),
#  ('Western Africa', 'Benin', 2017, Decimal('11.596779'), Decimal('24.3887')),
#  ('Western Africa', 'Niger', 2017, Decimal('21.737922'), Decimal('24.3887')),
#  ('Western Africa', 'Liberia', 2017, Decimal('4.796631'), Decimal('24.3887')),
#  ('Western Africa', 'Guinea', 2017, Decimal('12.240789'), Decimal('24.3887')),
#  ('Western Africa', 'Nigeria', 2017, Decimal('193.495907'), Decimal('24.3887')),
#  ('Western Africa', 'Burkina Faso', 2017, Decimal('19.835858'), Decimal('24.3887')),
#  ('Western Africa', 'Senegal', 2017, Decimal('15.157793'), Decimal('24.3887')),
#  ('Western Africa', 'Cabo Verde', 2017, Decimal('0.564954'), Decimal('24.3887')),
#  ('Western Africa', 'Guinea-Bissau', 2017, Decimal('1.879826'), Decimal('24.3887')),
#  ('Western Africa', 'Sierra Leone', 2017, Decimal('7.677565'), Decimal('24.3887')),
#  ('Western Africa', 'Mauritania', 2017, Decimal('4.160015'), Decimal('24.3887')),
#  ('Western Africa', 'Ghana', 2017, Decimal('30.222262'), Decimal('24.3887')),
#  ('Western Africa', 'Togo', 2017, Decimal('7.852795'), Decimal('24.3887')),
#  ('Western Africa', 'Mali', 2018, Decimal('19.934298'), Decimal('24.7165')),
#  ('Western Africa', 'Burkina Faso', 2018, Decimal('20.392723'), Decimal('24.7165')),
#  ('Western Africa', 'Nigeria', 2018, Decimal('198.387623'), Decimal('24.7165')),
#  ('Western Africa', 'Guinea-Bissau', 2018, Decimal('1.924955'), Decimal('24.7165')),
#  ('Western Africa', 'Benin', 2018, Decimal('11.940683'), Decimal('24.7165')),
#  ('Western Africa', 'Senegal', 2018, Decimal('15.574909'), Decimal('24.7165')),
#  ('Western Africa', 'Mauritania', 2018, Decimal('4.270712'), Decimal('24.7165')),
#  ('Western Africa', 'Guinea', 2018, Decimal('12.554864'), Decimal('24.7165')),
#  ('Western Africa', 'Liberia', 2018, Decimal('4.889391'), Decimal('24.7165')),
#  ('Western Africa', 'Sierra Leone', 2018, Decimal('7.861281'), Decimal('24.7165')),
#  ('Western Africa', 'Cabo Verde', 2018, Decimal('0.571202'), Decimal('24.7165')),
#  ('Western Africa', 'Niger', 2018, Decimal('22.577058'), Decimal('24.7165')),
#  ('Western Africa', 'Ghana', 2018, Decimal('30.870641'), Decimal('24.7165')),
#  ('Western Africa', 'Togo', 2018, Decimal('8.046679'), Decimal('24.7165')),
#  ('Western Africa', 'Cabo Verde', 2019, Decimal('0.577030'), Decimal('25.0470')),
#  ('Western Africa', 'Ghana', 2019, Decimal('31.522290'), Decimal('25.0470')),
#  ('Western Africa', 'Mali', 2019, Decimal('20.567424'), Decimal('25.0470')),
#  ('Western Africa', 'Senegal', 2019, Decimal('16.000781'), Decimal('25.0470')),
#  ('Western Africa', 'Burkina Faso', 2019, Decimal('20.951639'), Decimal('25.0470')),
#  ('Western Africa', 'Niger', 2019, Decimal('23.443393'), Decimal('25.0470')),
#  ('Western Africa', 'Guinea', 2019, Decimal('12.877539'), Decimal('25.0470')),
#  ('Western Africa', 'Liberia', 2019, Decimal('4.985289'), Decimal('25.0470')),
#  ('Western Africa', 'Sierra Leone', 2019, Decimal('8.046828'), Decimal('25.0470')),
#  ('Western Africa', 'Guinea-Bissau', 2019, Decimal('1.970457'), Decimal('25.0470')),
#  ('Western Africa', 'Mauritania', 2019, Decimal('4.383849'), Decimal('25.0470')),
#  ('Western Africa', 'Nigeria', 2019, Decimal('203.304492'), Decimal('25.0470')),
#  ('Western Africa', 'Benin', 2019, Decimal('12.290444'), Decimal('25.0470')),
#  ('Western Africa', 'Togo', 2019, Decimal('8.243094'), Decimal('25.0470')),
#  ('Western Africa', 'Niger', 2020, Decimal('24.333639'), Decimal('25.3812')),
#  ('Western Africa', 'Senegal', 2020, Decimal('16.436120'), Decimal('25.3812')),
#  ('Western Africa', 'Liberia', 2020, Decimal('5.087584'), Decimal('25.3812')),
#  ('Western Africa', 'Guinea-Bissau', 2020, Decimal('2.015828'), Decimal('25.3812')),
#  ('Western Africa', 'Benin', 2020, Decimal('12.643123'), Decimal('25.3812')),
#  ('Western Africa', 'Mauritania', 2020, Decimal('4.498604'), Decimal('25.3812')),
#  ('Western Africa', 'Burkina Faso', 2020, Decimal('21.522626'), Decimal('25.3812')),
#  ('Western Africa', 'Sierra Leone', 2020, Decimal('8.233970'), Decimal('25.3812')),
#  ('Western Africa', 'Nigeria', 2020, Decimal('208.327405'), Decimal('25.3812')),
#  ('Western Africa', 'Ghana', 2020, Decimal('32.180401'), Decimal('25.3812')),
#  ('Western Africa', 'Mali', 2020, Decimal('21.224040'), Decimal('25.3812')),
#  ('Western Africa', 'Cabo Verde', 2020, Decimal('0.582640'), Decimal('25.3812')),
#  ('Western Africa', 'Guinea', 2020, Decimal('13.205153'), Decimal('25.3812')),
#  ('Western Africa', 'Togo', 2020, Decimal('8.442580'), Decimal('25.3812')),
#  ('Western Asia', 'Oman', 2015, Decimal('4.191776'), Decimal('10.1481')),
#  ('Western Asia', 'Cyprus', 2015, Decimal('1.187280'), Decimal('10.1481')),
#  ('Western Asia', 'Georgia', 2015, Decimal('3.725276'), Decimal('10.1481')),
#  ('Western Asia', 'United Arab Emirates', 2015, Decimal('8.916899'), Decimal('10.1481')),
#  ('Western Asia', 'Armenia', 2015, Decimal('2.878595'), Decimal('10.1481')),
#  ('Western Asia', 'Jordan', 2015, Decimal('9.494246'), Decimal('10.1481')),
#  ('Western Asia', 'Lebanon', 2015, Decimal('6.398940'), Decimal('10.1481')),
#  ('Western Asia', 'Azerbaijan', 2015, Decimal('9.649341'), Decimal('10.1481')),
#  ('Western Asia', 'Iraq', 2015, Decimal('37.757813'), Decimal('10.1481')),
#  ('Western Asia', 'Qatar', 2015, Decimal('2.414573'), Decimal('10.1481')),
#  ('Western Asia', 'Bahrain', 2015, Decimal('1.362142'), Decimal('10.1481')),
#  ('Western Asia', 'Syrian Arab Republic', 2015, Decimal('19.205178'), Decimal('10.1481')),
#  ('Western Asia', 'Kuwait', 2015, Decimal('3.908743'), Decimal('10.1481')),
#  ('Western Asia', 'Saudi Arabia', 2015, Decimal('32.749848'), Decimal('10.1481')),
#  ('Western Asia', 'Israel', 2015, Decimal('8.380100'), Decimal('10.1481')),
#  ('Western Asia', 'Jordan', 2016, Decimal('9.964656'), Decimal('10.2354')),
#  ('Western Asia', 'Georgia', 2016, Decimal('3.727505'), Decimal('10.2354')),
#  ('Western Asia', 'Cyprus', 2016, Decimal('1.197881'), Decimal('10.2354')),
#  ('Western Asia', 'Oman', 2016, Decimal('4.398070'), Decimal('10.2354')),
#  ('Western Asia', 'Lebanon', 2016, Decimal('6.258619'), Decimal('10.2354')),
#  ('Western Asia', 'Bahrain', 2016, Decimal('1.409661'), Decimal('10.2354')),
#  ('Western Asia', 'Armenia', 2016, Decimal('2.865835'), Decimal('10.2354')),
#  ('Western Asia', 'Israel', 2016, Decimal('8.546000'), Decimal('10.2354')),
#  ('Western Asia', 'United Arab Emirates', 2016, Decimal('8.994263'), Decimal('10.2354')),
#  ('Western Asia', 'Kuwait', 2016, Decimal('4.048085'), Decimal('10.2354')),
#  ('Western Asia', 'Syrian Arab Republic', 2016, Decimal('18.964252'), Decimal('10.2354')),
#  ('Western Asia', 'Saudi Arabia', 2016, Decimal('33.416270'), Decimal('10.2354')),
#  ('Western Asia', 'Qatar', 2016, Decimal('2.595166'), Decimal('10.2354')),
#  ('Western Asia', 'Iraq', 2016, Decimal('38.697943'), Decimal('10.2354')),
#  ('Western Asia', 'Azerbaijan', 2016, Decimal('9.757812'), Decimal('10.2354')),
#  ('Western Asia', 'Kuwait', 2017, Decimal('4.124904'), Decimal('10.3210')),
#  ('Western Asia', 'Syrian Arab Republic', 2017, Decimal('18.983373'), Decimal('10.3210')),
#  ('Western Asia', 'Cyprus', 2017, Decimal('1.208523'), Decimal('10.3210')),
#  ('Western Asia', 'Lebanon', 2017, Decimal('6.109252'), Decimal('10.3210')),
#  ('Western Asia', 'Israel', 2017, Decimal('8.713300'), Decimal('10.3210')),
#  ('Western Asia', 'Armenia', 2017, Decimal('2.851923'), Decimal('10.3210')),
#  ('Western Asia', 'Saudi Arabia', 2017, Decimal('34.193122'), Decimal('10.3210')),
#  ('Western Asia', 'United Arab Emirates', 2017, Decimal('9.068296'), Decimal('10.3210')),
#  ('Western Asia', 'Iraq', 2017, Decimal('39.621162'), Decimal('10.3210')),
#  ('Western Asia', 'Qatar', 2017, Decimal('2.711755'), Decimal('10.3210')),
#  ('Western Asia', 'Georgia', 2017, Decimal('3.728004'), Decimal('10.3210')),
#  ('Western Asia', 'Jordan', 2017, Decimal('10.215381'), Decimal('10.3210')),
#  ('Western Asia', 'Bahrain', 2017, Decimal('1.456834'), Decimal('10.3210')),
#  ('Western Asia', 'Azerbaijan', 2017, Decimal('9.854033'), Decimal('10.3210')),
#  ('Western Asia', 'Oman', 2017, Decimal('4.541854'), Decimal('10.3210')),
#  ('Western Asia', 'Saudi Arabia', 2018, Decimal('35.018133'), Decimal('10.4119')),
#  ('Western Asia', 'Lebanon', 2018, Decimal('5.950839'), Decimal('10.4119')),
#  ('Western Asia', 'United Arab Emirates', 2018, Decimal('9.140169'), Decimal('10.4119')),
#  ('Western Asia', 'Bahrain', 2018, Decimal('1.487340'), Decimal('10.4119')),
#  ('Western Asia', 'Kuwait', 2018, Decimal('4.317185'), Decimal('10.4119')),
#  ('Western Asia', 'Armenia', 2018, Decimal('2.836557'), Decimal('10.4119')),
#  ('Western Asia', 'Syrian Arab Republic', 2018, Decimal('19.333463'), Decimal('10.4119')),
#  ('Western Asia', 'Georgia', 2018, Decimal('3.726549'), Decimal('10.4119')),
#  ('Western Asia', 'Jordan', 2018, Decimal('10.459865'), Decimal('10.4119')),
#  ('Western Asia', 'Qatar', 2018, Decimal('2.766732'), Decimal('10.4119')),
#  ('Western Asia', 'Oman', 2018, Decimal('4.601157'), Decimal('10.4119')),
#  ('Western Asia', 'Israel', 2018, Decimal('8.882800'), Decimal('10.4119')),
#  ('Western Asia', 'Iraq', 2018, Decimal('40.590700'), Decimal('10.4119')),
#  ('Western Asia', 'Azerbaijan', 2018, Decimal('9.939771'), Decimal('10.4119')),
#  ('Western Asia', 'Cyprus', 2018, Decimal('1.218831'), Decimal('10.4119')),
#  ('Western Asia', 'Lebanon', 2019, Decimal('5.781907'), Decimal('10.5079')),
#  ('Western Asia', 'Kuwait', 2019, Decimal('4.441100'), Decimal('10.5079')),
#  ('Western Asia', 'Jordan', 2019, Decimal('10.698683'), Decimal('10.5079')),
#  ('Western Asia', 'United Arab Emirates', 2019, Decimal('9.211657'), Decimal('10.5079')),
#  ('Western Asia', 'Azerbaijan', 2019, Decimal('10.024283'), Decimal('10.5079')),
#  ('Western Asia', 'Syrian Arab Republic', 2019, Decimal('20.098251'), Decimal('10.5079')),
#  ('Western Asia', 'Cyprus', 2019, Decimal('1.228836'), Decimal('10.5079')),
#  ('Western Asia', 'Bahrain', 2019, Decimal('1.494188'), Decimal('10.5079')),
#  ('Western Asia', 'Armenia', 2019, Decimal('2.820602'), Decimal('10.5079')),
#  ('Western Asia', 'Saudi Arabia', 2019, Decimal('35.827362'), Decimal('10.5079')),
#  ('Western Asia', 'Iraq', 2019, Decimal('41.563520'), Decimal('10.5079')),
#  ('Western Asia', 'Georgia', 2019, Decimal('3.720161'), Decimal('10.5079')),
#  ('Western Asia', 'Qatar', 2019, Decimal('2.807235'), Decimal('10.5079')),
#  ('Western Asia', 'Israel', 2019, Decimal('9.054000'), Decimal('10.5079')),
#  ('Western Asia', 'Oman', 2019, Decimal('4.602768'), Decimal('10.5079')),
#  ('Western Asia', 'Kuwait', 2020, Decimal('4.360444'), Decimal('10.5946')),
#  ('Western Asia', 'Jordan', 2020, Decimal('10.928721'), Decimal('10.5946')),
#  ('Western Asia', 'Israel', 2020, Decimal('9.215100'), Decimal('10.5946')),
#  ('Western Asia', 'Bahrain', 2020, Decimal('1.477469'), Decimal('10.5946')),
#  ('Western Asia', 'Saudi Arabia', 2020, Decimal('35.997107'), Decimal('10.5946')),
#  ('Western Asia', 'Azerbaijan', 2020, Decimal('10.093121'), Decimal('10.5946')),
#  ('Western Asia', 'Iraq', 2020, Decimal('42.556984'), Decimal('10.5946')),
#  ('Western Asia', 'Qatar', 2020, Decimal('2.760385'), Decimal('10.5946')),
#  ('Western Asia', 'Armenia', 2020, Decimal('2.805608'), Decimal('10.5946')),
#  ('Western Asia', 'United Arab Emirates', 2020, Decimal('9.287289'), Decimal('10.5946')),
#  ('Western Asia', 'Georgia', 2020, Decimal('3.722716'), Decimal('10.5946')),
#  ('Western Asia', 'Oman', 2020, Decimal('4.543399'), Decimal('10.5946')),
#  ('Western Asia', 'Cyprus', 2020, Decimal('1.237537'), Decimal('10.5946')),
#  ('Western Asia', 'Lebanon', 2020, Decimal('5.662923'), Decimal('10.5946')),
#  ('Western Asia', 'Syrian Arab Republic', 2020, Decimal('20.772595'), Decimal('10.5946'))]

# %% [markdown]
# ## Solutions
#
# ### Task 1: Select the data required for the analysis

# %%
# %%sql
# SELECT
# 	Sub_region,
#     Country_name,
#     Land_area
# FROM united_nations.Access_to_Basic_Services
# WHERE Time_period = 2020
# AND Land_area IS NOT NULL;

# %% [markdown]
# ### Task 2: Calculate the land area covered as a percentage of the country's subregion

# %%
# %%sql
# SELECT
#     Sub_region,
#     Country_name,
#     Land_area,
#     ROUND(Land_area/SUM(Land_area) OVER (PARTITION BY sub_region)*100,4) AS pct_sub_region_land_area
# FROM united_nations.access_to_basic_services
#     WHERE time_period = 2020
#     AND Land_area IS NOT NULL;

# %% [markdown]
# ### Task 3: Calculate The running population average for each country's subregion

# %%
# %%sql
# SELECT
#     Sub_region,
#     Country_name,
#     Time_period,
#     Pct_managed_drinking_water_services,
#     Pct_managed_sanitation_services,
#     Est_gdp_in_billions,
#     Est_population_in_millions,
#     ROUND(AVG(Est_population_in_millions) OVER (PARTITION BY Sub_region ORDER BY Time_period),4) AS Running_average_population
# FROM united_nations.access_to_basic_services
#     WHERE Est_gdp_in_billions IS NOT NULL;

# %% [markdown]
# <div align="center" style=" font-size: 80%; text-align: center; margin: 0 auto">
# <img src="https://raw.githubusercontent.com/Explore-AI/Pictures/refs/heads/master/ALX_banners/ALX_Navy.png"  style="width:100px"  ;/>
# </div>
