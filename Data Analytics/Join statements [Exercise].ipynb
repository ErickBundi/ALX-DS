# %% [markdown]
# <div align="right" style=" font-size: 80%; text-align: center; margin: 0 auto">
# <img
#  src="https://raw.githubusercontent.com/Explore-AI/Pictures/master/alx-courses/aice/assets/Content_page_banner_blue_dots.png"
#  alt="ALX Content Header"
#  class="full-width-image"
# />
# </div>

# %% [markdown]
# # Join statements

# %% [markdown]
# In this exercise,  we will explore different SQL `JOIN` statements in order to cross-examine data contained in multiple tables in a dataset.

# %% [markdown]
# > ⚠️ In this exercise, we will query a sample SQLite database file called Chinook to gain some insight into the data. Ensure that you have downloaded the database file, `chinook.db`.

# %% [markdown]
# ## Learning objectives
#
# In this train, we will learn how to:
# - Join multiple tables.
# - Find common information between tables.
# - Use a `LEFT JOIN` to check for missing information.
# - Use `CROSS JOIN` to find all the possible combinations of required table rows.

# %% [markdown]
# First, let's load our sample database:

# %%
# load and activate the SQL extension to allow us to execute SQL in a Jupyter notebook
# %load_ext sql

# Load the Chinook database stored in your local machine. 
# Make sure the file is saved in the same folder as this notebook.
# %sql sqlite:///chinook.db

# %% [markdown]
# <div align="center" style=" font-size: 80%; text-align: center; margin: 0 auto">
# <img src="https://raw.githubusercontent.com/Explore-AI/Pictures/master/The%20chinook%20database%20ERD.jpeg"/>
# <br>
# <br>
#     <em>Figure 1: The Chinook database ERD</em>
# </div>

# %% [markdown]
# ## Overview
# Run the necessary queries that will provide us with the following information. Compare your queries with the solutions at the end of this notebook.

# %% [markdown]
# ### Exercise 1
#
# Sometimes artists add a title track to their albums. This is a track that has the same title as the album. Write a query that returns albums that have a title track.
# Return rows in the AlbumId column from the albums table, Title from the albums table, and the Name from the tracks table, where the album table Title column matches the tracks table Name column.

# %%
# %%sql
#
# SELECT
#     albums.AlbumId,
#     albums.Title,
#     tracks.Name
# FROM
#     albums
# INNER JOIN tracks
# ON albums.AlbumId = tracks.AlbumId
# WHERE albums.Title = tracks.Name
# LIMIT 5;
# Out:
#  * sqlite:///chinook.db
# Done.
# [(2, 'Balls to the Wall', 'Balls to the Wall'),
#  (3, 'Restless and Wild', 'Restless and Wild'),
#  (4, 'Let There Be Rock', 'Let There Be Rock'),
#  (11, 'Out Of Exile', 'Out Of Exile'),
#  (16, 'Black Sabbath', 'Black Sabbath')]

# %% [markdown]
# ### Exercise 2
#
# Suppose that in the previous exercise, we were additionally interested in knowing who the artists of the listed albums are. Write a query that can achieve this.

# %%
# %%sql
#
# SELECT
#     albums.AlbumId,
#     albums.Title AS "Album Title",
#     tracks.Name AS "Track Name",
#     artists.Name AS "Artist Name"
# FROM
#     albums
# INNER JOIN
#     tracks ON albums.AlbumId = tracks.AlbumId
# INNER JOIN
#     artists ON albums.ArtistId = artists.ArtistId
# WHERE
#     albums.Title = tracks.Name
# LIMIT 5;
# Out:
#  * sqlite:///chinook.db
# Done.
# [(2, 'Balls to the Wall', 'Balls to the Wall', 'Accept'),
#  (3, 'Restless and Wild', 'Restless and Wild', 'Accept'),
#  (4, 'Let There Be Rock', 'Let There Be Rock', 'AC/DC'),
#  (11, 'Out Of Exile', 'Out Of Exile', 'Audioslave'),
#  (16, 'Black Sabbath', 'Black Sabbath', 'Black Sabbath')]

# %% [markdown]
# ### Exercise 3
#
# One use case for a `LEFT JOIN` is that it can be used to check for missing information. In this case, try to find out what media items have not been bought yet (i.e. are not an item in any invoice).

# %%
# %%sql
#
# SELECT
#     tracks.TrackId,
#     tracks.Name AS "Track Name"
# FROM
#     tracks
# LEFT JOIN
#     invoice_items
# ON tracks.TrackId = invoice_items.TrackId
# WHERE
#     invoice_items.TrackId IS NULL;
# Out:
#  * sqlite:///chinook.db
# Done.
# [(7, "Let's Get It Up"),
#  (11, 'C.O.D.'),
#  (17, 'Let There Be Rock'),
#  (18, 'Bad Boy Boogie'),
#  (22, 'Whole Lotta Rosie'),
#  (23, 'Walk On Water'),
#  (27, 'Dude (Looks Like A Lady)'),
#  (29, "Cryin'"),
#  (33, 'The Other Side'),
#  (34, 'Crazy'),
#  (35, 'Eat The Rich'),
#  (40, 'Perfect'),
#  (41, 'Hand In My Pocket'),
#  (45, 'Head Over Feet'),
#  (46, 'Mary Jane'),
#  (47, 'Ironic'),
#  (50, 'You Oughta Know (Alternate)'),
#  (51, 'We Die Young'),
#  (52, 'Man In The Box'),
#  (56, 'Love, Hate, Love'),
#  (58, 'Sunshine'),
#  (59, 'Put You Down'),
#  (63, 'Desafinado'),
#  (64, 'Garota De Ipanema'),
#  (65, 'Samba De Uma Nota Só (One Note Samba)'),
#  (68, 'Fotografia'),
#  (69, 'Dindi (Dindi)'),
#  (70, 'Se Todos Fossem Iguais A Você (Instrumental)'),
#  (73, 'Corcovado (Quiet Nights Of Quiet Stars)'),
#  (74, 'Outra Vez'),
#  (77, 'Enter Sandman'),
#  (79, 'Harvester Of Sorrow'),
#  (81, 'Sad But True'),
#  (82, 'Creeping Death'),
#  (83, 'Wherever I May Roam'),
#  (86, 'Show Me How to Live'),
#  (87, 'Gasoline'),
#  (88, 'What You Are'),
#  (91, 'Shadow on the Sun'),
#  (92, 'I am the Highway'),
#  (95, "Bring'em Back Alive"),
#  (96, 'Light My Way'),
#  (97, 'Getaway Car'),
#  (100, 'Out Of Exile'),
#  (101, 'Be Yourself'),
#  (104, "Heaven's Dead"),
#  (105, 'The Worm'),
#  (106, 'Man Or Animal'),
#  (109, '#1 Zero'),
#  (110, 'The Curse'),
#  (113, 'Bad Boy'),
#  (114, 'Twist And Shout'),
#  (115, 'Please Mr. Postman'),
#  (118, 'Slow Down'),
#  (119, 'Roadrunner'),
#  (122, '20 Flight Rock'),
#  (123, 'Quadrant'),
#  (124, "Snoopy's search-Red baron"),
#  (127, 'Stratus'),
#  (128, 'The pleasant pheasant'),
#  (131, 'Intro/ Low Down'),
#  (132, '13 Years Of Grief'),
#  (133, 'Stronger Than Death'),
#  (136, 'Phoney Smile Fake Hellos'),
#  (137, 'Lost My Better Half'),
#  (140, 'Born To Booze'),
#  (141, 'World Of Trouble'),
#  (142, 'No More Tears'),
#  (145, 'Snowblind'),
#  (146, 'Like A Bird'),
#  (149, 'Black Sabbath'),
#  (150, 'The Wizard'),
#  (151, 'Behind The Wall Of Sleep'),
#  (154, 'Sleeping Village'),
#  (155, 'Warning'),
#  (156, 'Wheels Of Confusion / The Straightener'),
#  (158, 'Changes'),
#  (159, 'FX'),
#  (160, 'Supernaut'),
#  (164, 'St. Vitus Dance'),
#  (168, 'Now Sports'),
#  (172, 'The Real Problem'),
#  (174, 'D Note'),
#  (176, 'The Winner Loses'),
#  (177, 'There Goes The Neighborhood'),
#  (178, 'Oprah'),
#  (181, "Momma's Gotta Die Tonight"),
#  (182, 'Freedom Of Speech'),
#  (197, 'Pretty Baby'),
#  (200, 'She Suits Me To A Tee'),
#  (201, 'Keep It To Myself (Aka Keep It To Yourself)'),
#  (203, 'Too Many Ways (Alternate)'),
#  (204, "Talkin' 'Bout Women Obviously"),
#  (212, 'Drão'),
#  (220, 'A Luz De Tieta'),
#  (224, 'Sozinho (Hitmakers Classic Radio Edit)'),
#  (226, 'Carolina'),
#  (227, 'Essa Moça Ta Diferente'),
#  (239, 'Brejo Da Cruz'),
#  (243, 'Vai Trabalhar Vagabundo'),
#  (249, 'Quilombo Groove [Instrumental]'),
#  (250, 'Macô'),
#  (254, 'O Encontro De Isaac Asimov Com Santos Dumont No Céu'),
#  (255, 'Corpo De Lama'),
#  (259, 'Baião Ambiental [Instrumental]'),
#  (261, 'Enquanto O Mundo Explode'),
#  (265, 'Samidarish [Instrumental]'),
#  (266, 'Maracatu Atômico [Atomic Version]'),
#  (267, 'Maracatu Atômico [Ragga Mix]'),
#  (272, 'Cidade'),
#  (273, 'Praiera'),
#  (277, 'Salustiano Song'),
#  (278, 'Antene Se'),
#  (279, 'Risoflora'),
#  (282, 'Girassol'),
#  (283, 'A Sombra Da Maldade'),
#  (284, 'Johnny B. Goode'),
#  (288, 'O Erê'),
#  (290, 'A Estrada'),
#  (291, 'Berlim'),
#  (295, 'Conciliação'),
#  (296, 'Realidade Virtual'),
#  (297, 'Mensagem'),
#  (300, 'O Erê'),
#  (301, 'A Sombra Da Maldade'),
#  (302, 'A Estrada'),
#  (305, 'Pensamento'),
#  (306, 'Realidade Virtual'),
#  (309, 'Downtown'),
#  (311, 'A Cor Do Sol'),
#  (313, 'Noite Do Prazer'),
#  (314, 'À Francesa'),
#  (315, 'Cada Um Cada Um (A Namoradeira)'),
#  (318, 'Férias'),
#  (319, 'Gostava Tanto De Você'),
#  (320, 'Flor Do Futuro'),
#  (323, 'Dig-Dig, Lambe-Lambe (Ao Vivo)'),
#  (324, 'Pererê'),
#  (327, 'Daniela'),
#  (328, 'Bate Lata'),
#  (329, 'Garotas do Brasil'),
#  (332, 'Reboladeira'),
#  (333, 'É que Nessa Encarnação Eu Nasci Manga'),
#  (336, 'Latinha de Cerveja'),
#  (337, 'You Shook Me'),
#  (338, "I Can't Quit You Baby"),
#  (341, 'The Girl I Love She Got Long Black Wavy Hair'),
#  (342, 'What is and Should Never Be'),
#  (345, 'Whole Lotta Love'),
#  (346, "Somethin' Else"),
#  (347, 'Communication Breakdown(3)'),
#  (350, 'How Many More Times'),
#  (351, 'Debra Kadabra'),
#  (354, "Poofter's Froth Wyoming Plans Ahead"),
#  (355, '200 Years Old'),
#  (356, 'Cucamonga'),
#  (359, 'Muffin Man'),
#  (360, 'Vai-Vai 2001'),
#  (363, 'Nene 2001'),
#  (364, 'Rosas De Ouro 2001'),
#  (365, 'Mocidade Alegre 2001'),
#  (368, 'Tucuruvi 2001'),
#  (369, 'Aguia De Ouro 2001'),
#  (372, 'Perola Negra 2001'),
#  (373, 'Sao Lucas 2001'),
#  (374, 'Guanabara'),
#  (377, 'A Paz'),
#  (378, 'Wave (Vou te Contar)'),
#  (381, 'Pode Parar'),
#  (382, 'Menino do Rio'),
#  (383, 'Ando Meio Desligado'),
#  (386, 'Menina Bonita'),
#  (387, 'Pescador de Ilusões'),
#  (388, 'À Vontade (Live Mix)'),
#  (390, 'Sambassim (dj patife remix)'),
#  (391, 'Garota De Ipanema'),
#  (392, 'Tim Tim Por Tim Tim'),
#  (396, 'Alô Alô Marciano'),
#  (400, 'Alice'),
#  (404, 'Mr Funk Samba'),
#  (406, 'Por Você'),
#  (408, 'Free Speech For The Dumb'),
#  (409, "It's Electric"),
#  (410, 'Sabbra Cadabra'),
#  (413, 'Loverman'),
#  (414, 'Mercyful Fate'),
#  (429, 'The Miracle'),
#  (432, 'Hammer To Fall'),
#  (433, 'Friends Will Be Friends'),
#  (435, 'One Vision'),
#  (436, 'Detroit Rock City'),
#  (444, 'Do You Love Me'),
#  (452, 'Rock And Roll All Nite'),
#  (456, 'Heart of the Night'),
#  (458, 'Westwood Moon'),
#  (459, 'Midnight'),
#  (471, 'Welcome To Paradise'),
#  (475, 'J.A.R. (Jason Andrew Relva)'),
#  (481, "Hitchin' A Ride"),
#  (482, 'Good Riddance (Time Of Your Life)'),
#  (486, 'Warning'),
#  (487, 'Waiting'),
#  (491, 'She Give Me ...'),
#  (493, 'Love Is Blind'),
#  (497, 'Midnight Blue'),
#  (498, 'Too Many Tears'),
#  (499, "Don't Lie To Me"),
#  (504, 'O Que É O Que É ?'),
#  (505, 'Sangrando'),
#  (509, 'Com A Perna No Mundo'),
#  (510, 'E Vamos À Luta'),
#  (511, 'Um Homem Também Chora (Guerreiro Menino)'),
#  (514, 'Espere Por Mim, Morena'),
#  (515, 'Meia-Lua Inteira'),
#  (516, 'Voce e Linda'),
#  (520, 'O Estrangeiro'),
#  (522, 'Qualquer Coisa'),
#  (523, 'Sampa'),
#  (527, 'Terra'),
#  (528, 'Alegria, Alegria'),
#  (529, 'Balada Do Louco'),
#  (532, 'Baby'),
#  (533, 'A E O Z'),
#  (534, 'Panis Et Circenses'),
#  (537, 'Bat Macumba'),
#  (538, 'Desculpe Babe'),
#  (541, 'Banho De Lua'),
#  (543, 'Burn'),
#  (545, 'Gypsy'),
#  (546, 'Lady Double Dealer'),
#  (547, 'Mistreated'),
#  (550, 'Custard Pie'),
#  (551, 'The Rover'),
#  (552, 'In My Time Of Dying'),
#  (555, 'Kashmir'),
#  (556, 'Imperatriz'),
#  (559, 'Mocidade'),
#  (560, 'Unidos Da Tijuca'),
#  (561, 'Salgueiro'),
#  (564, 'Grande Rio'),
#  (565, 'Portela'),
#  (568, 'Império Serrano'),
#  (569, 'Tuiuti'),
#  (570, '(Da Le) Yaleo'),
#  (573, 'Africa Bamba'),
#  (574, 'Smooth'),
#  (577, 'Migra'),
#  (578, 'Corazon Espinado'),
#  (579, 'Wishing It Was'),
#  (582, 'The Calling'),
#  (583, 'Solução'),
#  (586, 'Um Contrato Com Deus'),
#  (587, 'Um Jantar Pra Dois'),
#  (588, 'Vamos Dançar'),
#  (591, 'Baixo Rio'),
#  (592, 'Sombras Do Meu Destino'),
#  (595, 'Já!!!'),
#  (596, 'A Rua'),
#  (597, "Now's The Time"),
#  (600, 'Tempus Fugit'),
#  (601, "Walkin'"),
#  (604, 'New Rhumba'),
#  (605, 'Generique'),
#  (606, 'Summertime'),
#  (609, 'Someday My Prince Will Come'),
#  (610, 'My Funny Valentine (Live)'),
#  (613, 'Petits Machins (Little Stuff)'),
#  (614, 'Miles Runs The Voodoo Down'),
#  (615, 'Little Church (Live)'),
#  (618, 'Time After Time'),
#  (619, 'Portia'),
#  (620, "Space Truckin'"),
#  (622, 'Mistreated (Alternate Version)'),
#  (623, 'You Fool No One (Alternate Version)'),
#  (624, 'Jeepers Creepers'),
#  (628, 'Leave Us Leap'),
#  (632, 'Disc Jockey Jump'),
#  (636, 'Coronation Drop'),
#  (638, 'Imagination'),
#  (640, 'Midget'),
#  (641, "I'm Coming Virginia"),
#  (642, "Payin' Them Dues Blues"),
#  (645, 'Swedish Schnapps'),
#  (646, 'Samba Da Bênção'),
#  (661, 'Linha de Passe (João Bosco)'),
#  (664, 'Marina (Dorival Caymmi)'),
#  (665, 'Aquarela (Toquinho)'),
#  (667, 'Dona (Roupa Nova)'),
#  (668, 'Começaria Tudo Outra Vez (Maria Creuza)'),
#  (676, 'I Put A Spell On You'),
#  (684, "Travelin' Band"),
#  (688, "Lookin' Out My Back Door"),
#  (690, 'I Heard It Through The Grapevine'),
#  (691, 'Have You Ever Seen The Rain?'),
#  (703, 'It Came Out Of The Sky'),
#  (707, 'My Baby Left Me'),
#  (713, "Lookin' For A Reason"),
#  (714, 'Hello Mary Lou'),
#  (718, 'Geração Coca-Cola (Ao Vivo)'),
#  (719, 'Lanterna Dos Afogados'),
#  (723, '1° De Julho'),
#  (725, 'Vida Bandida (Ao Vivo)'),
#  (729, 'Juventude Transviada (Ao Vivo)'),
#  (730, 'Malandragem'),
#  (731, 'O Segundo Sol'),
#  (736, 'Nós (Ao Vivo)'),
#  (737, 'Na Cadência Do Samba'),
#  (741, 'Blues Da Piedade'),
#  (742, 'Rubens'),
#  (743, 'Não Deixe O Samba Morrer - Cassia Eller e Alcione'),
#  (746, 'Lady Luck'),
#  (747, "Gettin' Tighter"),
#  (748, 'Dealer'),
#  (752, "This Time Around / Owed to 'G' [Instrumental]"),
#  (754, 'Speed King'),
#  (755, 'Bloodsucker'),
#  (759, 'Living Wreck'),
#  (760, "Hard Lovin' Man"),
#  (761, 'Fireball'),
#  (764, "Anyone's Daughter"),
#  (765, 'The Mule'),
#  (766, 'Fools'),
#  (769, 'Bad Attitude'),
#  (770, 'Child In Time (Son Of Aleric - Instrumental)'),
#  (773, 'Perfect Strangers'),
#  (775, 'Call Of The Wild'),
#  (777, 'Smoke On The Water'),
#  (778, 'Space Trucking'),
#  (779, 'Highway Star'),
#  (782, 'Never Before'),
#  (783, 'Smoke On The Water'),
#  (784, 'Lazy'),
#  (787, 'Loosen My Strings'),
#  (788, 'Soon Forgotten'),
#  (791, 'The Aviator'),
#  (792, "Rosa's Cantina"),
#  (793, 'A Castle Full Of Rascals'),
#  (796, 'Somebody Stole My Guitar'),
#  (797, 'The Purpendicular Waltz'),
#  (800, 'Fire In The Basement'),
#  (801, 'Truth Hurts'),
#  (802, 'Breakfast In Bed'),
#  (805, 'Too Much Is Not Enough'),
#  (806, 'Wicked Ways'),
#  (809, 'Holy Man'),
#  (810, 'Hold On'),
#  (811, 'Lady Double Dealer'),
#  (814, 'The Gypsy'),
#  (815, 'Soldier Of Fortune'),
#  (818, 'Anya'),
#  (819, 'Talk About Love'),
#  (820, 'Time To Kill'),
#  (823, 'Nasty Piece Of Work'),
#  (824, 'Solitaire'),
#  (827, 'Photograph'),
#  (828, 'Love Bites'),
#  (829, "Let's Get Rocked"),
#  (832, 'Heaven Is'),
#  (833, 'Rocket'),
#  (836, 'Make Love Like A Man'),
#  (837, 'Armageddon It'),
#  (838, 'Have You Ever Needed Someone So Bad'),
#  (841, "Bringin' On The Heartbreak"),
#  (842, 'Roll Call'),
#  (845, 'Paris On Mine'),
#  (846, 'In Time'),
#  (847, 'Plan B'),
#  (850, 'Talkin Loud and Saying Nothin'),
#  (851, 'Pétala'),
#  (852, 'Meu Bem-Querer'),
#  (854, 'Boa Noite'),
#  (855, 'Fato Consumado'),
#  (856, 'Faltando Um Pedaço'),
#  (860, 'Eu Te Devoro'),
#  (864, 'Samurai'),
#  (868, 'Serrado'),
#  (870, 'Amar É Tudo'),
#  (872, 'Seduzir'),
#  (873, 'A Carta'),
#  (874, 'Sina'),
#  (877, 'O Bêbado e a Equilibrista'),
#  (878, 'O Mestre-Sala dos Mares'),
#  (893, 'I Feel Free'),
#  (896, 'Strange Brew'),
#  (897, 'White Room'),
#  (899, 'Cocaine'),
#  (900, 'I Shot The Sheriff'),
#  (908, "I Can't Stand It"),
#  (916, 'Running On Faith'),
#  (920, 'Malted Milk'),
#  (922, "Rollin' And Tumblin'"),
#  (923, 'Collision'),
#  (935, 'Land Of Sunshine'),
#  (939, 'Smaller And Smaller'),
#  (945, 'Crack Hitler'),
#  (946, 'Jizzlobber'),
#  (950, 'Ricochet'),
#  (951, 'Evidence'),
#  (955, 'Caralho Voador'),
#  (957, 'Digging The Grave'),
#  (961, 'The Last To Know'),
#  (962, 'Just A Man'),
#  (963, 'Absolute Zero'),
#  (968, 'Zombie Eaters'),
#  (969, 'The Real Thing'),
#  (973, 'War Pigs'),
#  (974, 'Edge Of The World'),
#  (975, 'Deixa Entrar'),
#  (978, 'Rindo À Toa'),
#  (979, 'Confidência'),
#  (980, 'Forró De Tóquio'),
#  (984, 'Asas'),
#  (986, 'Oração'),
#  (987, 'Minha Gata'),
#  (991, 'Best Of You'),
#  (992, 'DOA'),
#  (993, 'Hell'),
#  (996, 'Resolve'),
#  (997, 'The Deepest Blues Are Black'),
#  (998, 'End Over End'),
#  (1001, 'Miracle'),
#  (1002, 'Another Round'),
#  (1005, 'On The Mend'),
#  (1007, 'Cold Day In The Sun'),
#  (1009, 'All My Life'),
#  (1010, 'Low'),
#  (1011, 'Have It All'),
#  (1014, 'Tired Of You'),
#  (1015, 'Halo'),
#  (1016, 'Lonely As You'),
#  (1019, 'Come Back'),
#  (1020, 'Doll'),
#  (1023, 'My Poor Brain'),
#  (1024, 'Wind Up'),
#  (1025, 'Up In Arms'),
#  (1028, 'Enough Space'),
#  (1029, 'February Stars'),
#  (1032, 'New Way Home'),
#  (1033, 'My Way'),
#  (1034, 'Strangers In The Night'),
#  (1037, 'Something Stupid'),
#  (1038, 'Moon River'),
#  (1041, 'For Once In My Life'),
#  (1042, 'Love And Marriage'),
#  (1043, "They Can't Take That Away From Me"),
#  (1046, "I've Got You Under My Skin"),
#  (1047, 'The Best Is Yet To Come'),
#  (1050, "That's Life"),
#  (1051, 'The Girl From Ipanema'),
#  (1052, 'The Lady Is A Tramp'),
#  (1055, 'Loves Been Good To Me'),
#  (1056, 'L.A. Is My Lady'),
#  (1059, 'Funk De Bamba (Com Fernanda Abreu)'),
#  (1060, 'Call Me At Cleo´s'),
#  (1061, 'Olhos Coloridos (Com Sandra De Sá)'),
#  (1064, 'Forty Days (Com DJ Hum)'),
#  (1065, 'Balada Da Paula'),
#  (1068, 'Motéis'),
#  (1069, 'Whistle Stop'),
#  (1070, '16 Toneladas'),
#  (1073, 'Óia Eu Aqui De Novo'),
#  (1074, 'Baião Da Penha'),
#  (1077, 'Último Pau-De-Arara'),
#  (1078, 'Asa Branca'),
#  (1079, 'Qui Nem Jiló'),
#  (1082, 'A Volta Da Asa Branca'),
#  (1083, 'O Amor Daqui De Casa'),
#  (1084, 'As Pegadas Do Amor'),
#  (1086, 'Casinha Feliz'),
#  (1087, 'Introdução (Live)'),
#  (1088, 'Palco (Live)'),
#  (1092, 'Vendedor De Caranguejo (Live)'),
#  (1096, 'Cérebro Eletrônico (Live)'),
#  (1100, 'Ghandi (Live)'),
#  (1102, 'Doce De Carnaval (Candy All)'),
#  (1104, 'Pretinha'),
#  (1105, 'A Novidade'),
#  (1106, 'Tenho Sede'),
#  (1109, 'Esotérico'),
#  (1110, 'Drão'),
#  (1125, 'I Stand Alone'),
#  (1128, 'Releasing The Demons'),
#  (1129, 'Dead And Broken'),
#  (1131, 'The Awakening'),
#  (1132, 'Serenity'),
#  (1140, "She's A Rebel"),
#  (1148, 'Nightrain'),
#  (1152, 'My Michelle'),
#  (1154, "Sweet Child O' Mine"),
#  (1155, "You're Crazy"),
#  (1167, 'November Rain'),
#  (1171, 'Bad Apples'),
#  (1177, "Knockin' On Heaven's Door"),
#  (1178, 'Get In The Ring'),
#  (1182, 'Locomotive'),
#  (1183, 'So Fine'),
#  (1187, 'My World'),
#  (1189, 'Love Is The Colour'),
#  (1193, 'Gypsy'),
#  (1194, 'Journey Into Sunlight'),
#  (1195, 'Sunchild'),
#  (1200, 'Dark Side Of The Cog'),
#  (1201, 'Different World'),
#  (1205, 'The Longest Day'),
#  (1206, 'Out of the Shadows'),
#  (1207, 'The Reincarnation of Benjamin Breeg'),
#  (1210, 'The Legacy'),
#  (1211, 'Hallowed Be Thy Name (Live) [Non Album Bonus Track]'),
#  (1212, 'The Number Of The Beast'),
#  (1216, 'Remember Tomorrow'),
#  (1218, 'Sanctuary'),
#  (1219, 'Running Free'),
#  (1223, 'Hallowed Be Thy Name'),
#  (1224, 'Be Quick Or Be Dead'),
#  (1225, 'From Here To Eternity'),
#  (1228, 'Tailgunner'),
#  (1229, 'The Evil That Men Do'),
#  (1230, 'Afraid To Shoot Strangers'),
#  (1233, 'The Clairvoyant'),
#  (1234, 'Fear Of The Dark'),
#  (1237, 'Brave New World'),
#  (1239, 'The Mercenary'),
#  (1241, 'The Fallen Angel'),
#  (1242, 'The Nomad'),
#  (1243, 'Out Of The Silent Planet'),
#  (1246, 'Rainmaker'),
#  (1247, 'No More Lies'),
#  (1248, 'Montsegur'),
#  (1251, 'New Frontier'),
#  (1252, 'Paschendale'),
#  (1255, 'Journeyman'),
#  (1256, 'Be Quick Or Be Dead'),
#  (1257, 'From Here To Eternity'),
#  (1260, "Childhood's End"),
#  (1261, 'Wasting Love'),
#  (1264, 'The Apparition'),
#  (1265, 'Judas Be My Guide'),
#  (1266, 'Weekend Warrior'),
#  (1269, '02 - Sanctuary'),
#  (1270, '03 - Remember Tomorrow'),
#  (1273, '06 - Transylvania'),
#  (1274, '07 - Strange World'),
#  (1275, '08 - Charlotte the Harlot'),
#  (1278, 'Wrathchild'),
#  (1279, 'Murders In The Rue Morgue'),
#  (1282, 'Innocent Exile'),
#  (1283, 'Killers'),
#  (1284, 'Prodigal Son'),
#  (1287, 'Intro- Churchill S Speech'),
#  (1288, 'Aces High'),
#  (1291, 'Revelations'),
#  (1292, 'Flight Of Icarus'),
#  (1293, 'Rime Of The Ancient Mariner'),
#  (1296, 'Hallowed Be Thy Name'),
#  (1297, 'Iron Maiden'),
#  (1300, 'Wrathchild'),
#  (1301, 'Acacia Avenue'),
#  (1302, 'Children Of The Damned'),
#  (1305, 'Be Quick Or Be Dead'),
#  (1306, 'The Number Of The Beast'),
#  (1309, 'Can I Play With Madness'),
#  (1310, 'Wasting Love'),
#  (1311, 'Tailgunner'),
#  (1314, 'Fear Of The Dark'),
#  (1315, 'Bring Your Daughter... To The Slaughter...'),
#  (1316, 'The Clairvoyant'),
#  (1318, 'Run To The Hills'),
#  (1319, '2 Minutes To Midnight'),
#  (1320, 'Iron Maiden'),
#  (1324, 'Running Free'),
#  (1328, 'Public Enema Number One'),
#  (1332, 'Hooks In You'),
#  (1334, 'Mother Russia'),
#  (1336, 'Revelations'),
#  (1337, 'Flight Of The Icarus'),
#  (1338, 'Die With Your Boots On'),
#  (1341, 'Quest For Fire'),
#  (1342, 'Sun And Steel'),
#  (1357, '2 Minutes To Midnight'),
#  (1360, 'The Mercenary'),
#  (1361, 'The Trooper'),
#  (1363, 'The Clansman'),
#  (1364, 'The Evil That Men Do'),
#  (1372, 'Infinite Dreams'),
#  (1380, 'Wasted Years'),
#  (1384, 'Alexander the Great'),
#  (1386, 'The Loneliness of the Long Dis'),
#  (1387, '22 Acacia Avenue'),
#  (1399, 'Look For The Truth'),
#  (1403, 'The Edge Of Darkness'),
#  (1409, 'The Clansman'),
#  (1410, 'When Two Worlds Collide'),
#  (1414, 'Please Please Please'),
#  (1415, 'Think'),
#  (1419, 'I Got You (I Feel Good)'),
#  (1421, 'Cold Sweat'),
#  (1425, 'Make It Funky Pt.1'),
#  (1426, "I'm A Greedy Man Pt.1"),
#  (1427, 'Get On The Good Foot'),
#  (1432, 'Hot Pants Pt.1'),
#  (1433, 'Soul Power (Live)'),
#  (1437, 'If I Like It, I Do It'),
#  (1438, 'Music Of The Wind'),
#  (1439, 'Emergency On Planet Earth'),
#  (1442, 'Revolution 1993'),
#  (1443, "Didgin' Out"),
#  (1444, 'Canned Heat'),
#  (1448, 'Failling'),
#  (1450, 'Supersonic'),
#  (1451, 'Butterfly'),
#  (1455, 'Just Another Story'),
#  (1456, 'Stillness In Time'),
#  (1457, 'Half The Man'),
#  (1460, 'The Kids'),
#  (1461, 'Mr. Moon'),
#  (1462, 'Scam'),
#  (1465, 'Space Cowboy'),
#  (1466, 'Last Chance'),
#  (1469, "Look What You've Done"),
#  (1471, 'Move On'),
#  (1473, 'Get Me Outta Here'),
#  (1474, 'Cold Hard Bitch'),
#  (1475, 'Come Around Again'),
#  (1478, 'Timothy'),
#  (1479, 'Foxy Lady'),
#  (1480, 'Manic Depression'),
#  (1483, 'Love Or Confusion'),
#  (1484, "I Don't Live Today"),
#  (1487, 'Third Stone From The Sun'),
#  (1488, 'Remember'),
#  (1489, 'Are You Experienced?'),
#  (1492, 'Purple Haze'),
#  (1493, '51st Anniversary'),
#  (1496, 'Surfing with the Alien'),
#  (1497, 'Ice 9'),
#  (1498, 'Crushing Day'),
#  (1501, 'Hill of the Skull'),
#  (1502, 'Circles'),
#  (1505, 'Echo'),
#  (1506, 'Engenho De Dentro'),
#  (1507, 'Alcohol'),
#  (1510, 'W/Brasil (Chama O Síndico)'),
#  (1511, 'País Tropical'),
#  (1514, 'Selassiê'),
#  (1515, 'Menina Sarará'),
#  (1516, 'Que Maravilha'),
#  (1519, 'Taj Mahal'),
#  (1520, 'Rapidamente'),
#  (1523, 'My Brother'),
#  (1524, 'Há Quanto Tempo'),
#  (1525, 'Vício'),
#  (1528, 'A Tarde'),
#  (1529, 'Always Be All Right'),
#  (1532, 'Pura Elegancia'),
#  (1533, 'Choramingando'),
#  (1534, 'Por Merecer'),
#  (1537, 'Cuando A Noite Vai Chegando'),
#  (1538, 'Naquele Dia'),
#  (1541, 'Cuando Eu For Pro Ceu'),
#  (1542, 'Do Nosso Amor'),
#  (1543, 'Borogodo'),
#  (1546, 'The Green Manalishi'),
#  (1547, 'Living After Midnight'),
#  (1548, 'Breaking The Law (Live)'),
#  (1550, 'Heading Out To The Highway (Live)'),
#  (1551, 'The Hellion'),
#  (1552, 'Electric Eye'),
#  (1556, 'Some Heads Are Gonna Roll'),
#  (1560, 'Victim Of Change (Live)'),
#  (1564, "Goin' Blind"),
#  (1566, 'Domino'),
#  (1568, 'A World Without Heroes'),
#  (1569, 'Rock Bottom'),
#  (1570, 'See You Tonight'),
#  (1573, '2,000 Man'),
#  (1574, 'Beth'),
#  (1589, "I Can't Quit You Baby"),
#  (1592, 'Darlene'),
#  (1593, "Bonzo's Montreux"),
#  (1595, 'The Song Remains The Same'),
#  (1596, 'The Rain Song'),
#  (1604, 'South Bound Saurez'),
#  (1612, 'The Battle Of Evermore'),
#  (1616, 'Going To California'),
#  (1618, 'Good Times Bad Times'),
#  (1619, "Babe I'm Gonna Leave You"),
#  (1631, 'Heartbreaker'),
#  (1635, 'Bring It On Home'),
#  (1641, 'Gallows Pole'),
#  (1642, 'Tangerine'),
#  (1646, 'In The Light'),
#  (1647, 'Bron-Yr-Aur'),
#  (1651, 'The Wanton Song'),
#  (1653, 'Black Country Woman'),
#  (1657, 'Royal Orleans'),
#  (1658, "Nobody's Fault But Mine"),
#  (1659, 'Candy Store Rock'),
#  (1664, 'The Song Remains The Same'),
#  (1665, 'Rain Song'),
#  (1669, 'Moby Dick'),
#  (1670, 'Whole Lotta Love'),
#  (1671, 'Natália'),
#  (1674, 'Longe Do Meu Lado'),
#  (1675, 'A Via Láctea'),
#  (1676, 'Música Ambiente'),
#  (1680, 'Mil Pedaços'),
#  (1682, '1º De Julho'),
#  (1683, 'Esperando Por Mim'),
#  (1687, 'Ainda É Cedo'),
#  (1688, 'Geração Coca-Cola'),
#  (1689, 'Eduardo E Mônica'),
#  (1692, 'Que País É Este'),
#  (1693, 'Faroeste Caboclo'),
#  (1694, 'Há Tempos'),
#  (1697, 'Vento No Litoral'),
#  (1698, 'Perfeição'),
#  (1701, 'Antes Das Seis'),
#  (1703, 'Fly Away'),
#  (1705, 'Again'),
#  (1706, "It Ain't Over 'Til It's Over"),
#  (1707, "Can't Get You Off My Mind"),
#  (1710, 'Stand By My Woman'),
#  (1711, 'Always On The Run'),
#  (1712, 'Heaven Help'),
#  (1715, 'Let Love Rule'),
#  (1716, 'Black Velveteen'),
#  (1719, 'Dancin´Days'),
#  (1720, 'Um Pro Outro'),
#  (1721, 'Aviso Aos Navegantes'),
#  (1724, 'Hyperconectividade'),
#  (1725, 'O Descobridor Dos Sete Mares'),
#  (1728, 'Um Certo Alguém'),
#  (1729, 'Fullgás'),
#  (1730, 'Sábado À Noite'),
#  (1733, 'Atrás Do Trio Elétrico'),
#  (1734, 'Senta A Pua'),
#  (1737, 'Toda Forma De Amor'),
#  (1738, 'Tudo Igual'),
#  (1739, 'Fogo De Palha'),
#  (1742, 'Se Você Pensa'),
#  (1743, 'Lá Vem O Sol (Here Comes The Sun)'),
#  (1746, 'Kayleigh'),
#  (1747, 'Lavender'),
#  (1748, 'Bitter Suite: Brief Encounter / Lost Weekend / Blue Angel'),
#  (1751, 'Lords Of The Backstage'),
#  (1752, 'Blind Curve: Vocal Under A Bloodlight / Passing Strangers / Mylo / Perimeter Walk / Threshold'),
#  (1755, 'Arrepio'),
#  (1756, 'Magamalabares'),
#  (1757, 'Chuva No Brejo'),
#  (1760, 'Maraçá'),
#  (1761, 'Blanco'),
#  (1764, 'Beija Eu'),
#  (1765, 'Give Me Love'),
#  (1766, 'Ainda Lembro'),
#  (1769, 'Ao Meu Redor'),
#  (1770, 'Bem Leve'),
#  (1773, 'Wherever I Lay My Hat'),
#  (1774, "Get My Hands On Some Lovin'"),
#  (1775, 'No Good Without You'),
#  (1778, "You're What's Happening (In The World Today)"),
#  (1779, 'Loving You Is Sweeter Than Ever'),
#  (1780, "It's A Bitter Pill To Swallow"),
#  (1782, "Gonna Keep On Tryin' Till I Win Your Love"),
#  (1783, "Gonna Give Her All The Love I've Got"),
#  (1784, 'I Wish It Would Rain'),
#  (1788, 'Ego Tripping Out'),
#  (1792, 'Overkill'),
#  (1796, 'Who Can It Be Now?'),
#  (1798, 'Dr. Heckyll & Mr. Jive'),
#  (1800, 'No Sign of Yesterday'),
#  (1801, 'Enter Sandman'),
#  (1802, 'Sad But True'),
#  (1805, 'Wherever I May Roam'),
#  (1806, "Don't Tread On Me"),
#  (1821, 'The Prince'),
#  (1824, 'Killing Time'),
#  (1825, 'Overkill'),
#  (1827, 'Stone Dead Forever'),
#  (1828, 'Too Late Too Late'),
#  (1836, 'No Remorse'),
#  (1844, 'Hero Of The Day'),
#  (1848, 'Wasted My Hate'),
#  (1850, 'Thorn Within'),
#  (1851, 'Ronnie'),
#  (1863, "Devil's Dance"),
#  (1867, 'Carpe Diem Baby'),
#  (1873, 'Fixxxer'),
#  (1874, 'Fight Fire With Fire'),
#  (1878, 'Trapped Under Ice'),
#  (1879, 'Escape'),
#  (1883, 'St. Anger'),
#  (1885, 'Dirty Window'),
#  (1889, 'Sweet Amber'),
#  (1890, 'The Unnamed Feeling'),
#  (1891, 'Purify'),
#  (1896, 'One'),
#  (1897, 'The Shortest Straw'),
#  (1901, 'Dyers Eve'),
#  (1902, 'Springsville'),
#  (1903, 'The Maids Of Cadiz'),
#  (1906, 'Miles Ahead'),
#  (1907, 'Blues For Pablo'),
#  (1908, 'New Rhumba'),
#  (1912, 'Springsville (Alternate Take)'),
#  (1914, 'The Meaning Of The Blues/Lament (Alternate Take)'),
#  (1915, "I Don't Wanna Be Kissed (By Anyone But You) (Alternate Take)"),
#  (1919, 'Cuitelinho'),
#  (1920, 'Caxangá'),
#  (1921, 'Nos Bailes Da Vida'),
#  (1924, 'Canção Do Novo Mundo'),
#  (1925, 'Um Gosto De Sol'),
#  (1926, 'Solar'),
#  (1929, 'Minas'),
#  (1930, 'Fé Cega, Faca Amolada'),
#  (1933, 'Gran Circo'),
#  (1935, 'Trastevere'),
#  (1937, 'Leila (Venha Ser Feliz)'),
#  (1938, 'Paula E Bebeto'),
#  (1939, 'Simples'),
#  (1942, 'Ace Of Spades'),
#  (1943, 'Love Me Like A Reptile'),
#  (1944, 'Shoot You In The Back'),
#  (1947, '(We Are) The Road Crew'),
#  (1948, 'Fire Fire'),
#  (1951, 'Bite The Bullet'),
#  (1952, 'The Chase Is Better Than The Catch'),
#  (1953, 'The Hammer'),
#  (1956, 'Emergency'),
#  (1957, 'Kir Royal'),
#  (1960, 'Dois Índios'),
#  (1961, 'Noite Negra'),
#  (1962, 'Beijo do Olhar'),
#  (1965, 'Só Se For Pelo Cabelo'),
#  (1966, 'No Clima'),
#  (1969, 'Bitter Pill'),
#  (1970, 'Enslaved'),
#  (1971, 'Girls, Girls, Girls'),
#  (1974, 'Glitter'),
#  (1975, 'Dr. Feelgood'),
#  (1978, 'Afraid'),
#  (1979, "Don't Go Away Mad (Just Go Away)"),
#  (1980, 'Without You'),
#  (1983, 'Too Fast For Love'),
#  (1984, 'Looks That Kill'),
#  (1987, 'School'),
#  (1988, 'Drain You'),
#  (1989, 'Aneurysm'),
#  (1992, 'Lithium'),
#  (1993, 'Sliver'),
#  (1996, 'Heart-Shaped Box'),
#  (1997, 'Milk It'),
#  (1998, 'Negative Creep'),
#  (2001, "Tourette's"),
#  (2002, 'Blew'),
#  (2005, 'Come As You Are'),
#  (2006, 'Breed'),
#  (2007, 'Lithium'),
#  (2010, 'Drain You'),
#  (2011, 'Lounge Act'),
#  (2012, 'Stay Away'),
#  (2014, 'Something In The Way'),
#  (2015, 'Time'),
#  (2016, 'P.S.Apareça'),
#  (2020, 'Mágica'),
#  (2024, 'Deus'),
#  (2028, 'Prazer E Fé'),
#  (2030, 'Requebra'),
#  (2032, 'Olodum - Alegria Geral'),
#  (2033, 'Madagáscar Olodum'),
#  (2034, 'Faraó Divindade Do Egito'),
#  (2037, 'Olodum, A Banda Do Pelô'),
#  (2038, 'Cartao Postal'),
#  (2053, 'Meu Erro'),
#  (2056, 'Tendo A Lua'),
#  (2057, 'Que País É Este'),
#  (2059, 'Feira Moderna'),
#  (2060, 'Tequila - Lourinha Bombril (Parate Y Mira)'),
#  (2068, 'Lourinha Bombril'),
#  (2076, 'Aonde Quer Que Eu Va'),
#  (2080, 'Alagados'),
#  (2082, 'Melô Do Marinheiro'),
#  (2083, 'Vital E Sua Moto'),
#  (2095, 'Crazy Train'),
#  (2099, "I Don't Know"),
#  (2105, 'Steal Away (The Night)'),
#  (2106, 'Suicide Solution (With Guitar Solo)'),
#  (2110, 'Goodbye To Romance'),
#  (2111, 'No Bone Movies'),
#  (2115, 'Upon A Golden Horse'),
#  (2117, 'Please Read The Letter'),
#  (2121, 'Burning Up'),
#  (2122, 'When I Was A Child'),
#  (2123, 'House Of Love'),
#  (2128, 'Always Forever Now'),
#  (2129, 'A Different Kind Of Blue'),
#  (2133, 'One Minute Warning'),
#  (2134, 'Corpse (These Chains Are Way Too Long)'),
#  (2135, 'Elvis Ate America'),
#  (2138, "Theme From Let's Go Native"),
#  (2139, 'Wrathchild'),
#  (2140, 'Killers'),
#  (2144, 'Remember Tomorrow'),
#  (2146, 'Running Free'),
#  (2147, 'Phantom Of The Opera'),
#  (2151, 'Hail, Hail'),
#  (2152, 'Daughter'),
#  (2153, 'Elderly Woman Behind The Counter In A Small Town'),
#  (2156, 'Go'),
#  (2157, 'Red Mosquito'),
#  (2158, 'Even Flow'),
#  (2161, 'Do The Evolution'),
#  (2162, 'Better Man'),
#  (2165, 'Life Wasted'),
#  (2167, 'Comatose'),
#  (2169, 'Marker In The Sand'),
#  (2170, 'Parachutes'),
#  (2171, 'Unemployable'),
#  (2174, 'Wasted Reprise'),
#  (2175, 'Army Reserve'),
#  (2176, 'Come Back'),
#  (2179, 'Save You'),
#  (2180, 'Love Boat Captain'),
#  (2183, 'I Am Mine'),
#  (2184, 'Thumbing My Way'),
#  (2185, 'You Are'),
#  (2188, 'Help Help'),
#  (2189, 'Bushleager'),
#  (2192, 'All or None'),
#  (2193, 'Once'),
#  (2194, 'Evenflow'),
#  (2197, 'Black'),
#  (2198, 'Jeremy'),
#  (2201, 'Garden'),
#  (2202, 'Deep'),
#  (2203, 'Release'),
#  (2206, 'Daughter'),
#  (2207, 'Glorified G'),
#  (2210, 'Blood'),
#  (2211, 'Rearviewmirror'),
#  (2212, 'Rats'),
#  (2215, 'Indifference'),
#  (2216, 'Johnny B. Goode'),
#  (2219, "I'm The Toughest"),
#  (2220, 'Nothing But Love'),
#  (2221, 'Buk-In-Hamm Palace'),
#  (2224, 'Mystic Man'),
#  (2225, 'Coming In Hot'),
#  (2228, 'Equal Rights Downpresser Man'),
#  (2229, 'Speak To Me/Breathe'),
#  (2230, 'On The Run'),
#  (2233, 'Money'),
#  (2234, 'Us And Them'),
#  (2237, 'Eclipse'),
#  (2238, 'ZeroVinteUm'),
#  (2239, 'Queimando Tudo'),
#  (2242, '100% HardCore'),
#  (2243, 'Biruta'),
#  (2244, 'Mão Na Cabeça'),
#  (2246, 'Adoled (Ocean)'),
#  (2247, 'Seus Amigos'),
#  (2248, 'Paga Pau'),
#  (2252, 'Quem Me Cobrou?'),
#  (2256, 'Killer Queen'),
#  (2260, "Don't Stop Me Now"),
#  (2262, 'Crazy Little Thing Called Love'),
#  (2264, "Now I'm Here"),
#  (2265, 'Good Old-Fashioned Lover Boy'),
#  (2266, 'Play The Game'),
#  (2269, 'We Will Rock You'),
#  (2270, 'We Are The Champions'),
#  (2285, 'Pop Song 89'),
#  (2288, 'Stand'),
#  (2289, 'World Leader Pretend'),
#  (2291, 'Orange Crush'),
#  (2292, 'Turn You Inside-Out'),
#  (2300, 'E-Bow The Letter'),
#  (2308, 'Low Desert'),
#  (2312, 'Near Wild Heaven'),
#  (2314, 'Belong'),
#  (2315, 'Half A World Away'),
#  (2327, 'Driver 8'),
#  (2331, 'The One I Love'),
#  (2337, 'Merry Christmas'),
#  (2338, 'Bodies'),
#  (2342, 'Cajueiro'),
#  (2343, 'Palhas Do Coqueiro'),
#  (2347, 'O Segredo Do Universo'),
#  (2349, 'Mata Virgem'),
#  (2353, 'Diamante De Mendigo'),
#  (2354, 'Negócio É'),
#  (2355, 'Muita Estrela, Pouca Constelação'),
#  (2360, 'Breaking The Girl'),
#  (2361, 'Funky Monks'),
#  (2365, 'The Righteous & The Wicked'),
#  (2366, 'Give It Away'),
#  (2367, 'Blood Sugar Sex Magik'),
#  (2370, 'Apache Rose Peacock'),
#  (2371, 'The Greeting Song'),
#  (2372, 'My Lovely Man'),
#  (2376, 'Universally Speaking'),
#  ...]

# %% [markdown]
# ### Exercise 4
#
# In the results, the tracks that have a value of `None` (i.e. `NULL`) for `InvoiceId` are the ones that have not been purchased yet. Add a `WHERE` clause to only focus on these 'unpopular' tracks.

# %%
# Add your code here

# %% [markdown]
# ### Exercise 5
#
# Let's suppose that, as part of a new business strategy, Chinook wants to develop new product categories for their media items that are based on genre and media type. Write a query that will list all possible product categories (i.e. all possible genre and media type combinations).

# %%
# Add your code here

# %% [markdown]
# ## Solutions

# %% [markdown]
# ### Exercise 1

# %%
# %%sql
#
# SELECT
#     a.AlbumId,
#     a.Title AS "Album Title",
#     t.Name AS "Track Name"
# FROM
#     albums a
# INNER JOIN
#     tracks AS t
#     ON a.Title = t.Name
# LIMIT 10;  -- Remove this line to see the full query output

# %% [markdown]
# ### Exercise 2

# %%
# %%sql
#
# SELECT
#     a.AlbumId,
#     a.Title AS "Album Title",
#     t.Name AS "Track Name",
#     ar.Name AS "Artist Name"
# FROM
#     albums AS a
# INNER JOIN
#     tracks AS t
#     ON a.Title = t.Name
# INNER JOIN
#     artists AS ar
#     ON ar.ArtistId = a.ArtistId
# LIMIT 10;  -- Remove this line to see the full query output

# %% [markdown]
# Return rows in the `AlbumId` from the `albums` table, `Title` from the `albums` table, the `Name` from the `tracks` table, and the `Name` from the `artists` table, where the `albums` table `Title` column matches the `tracks` table `Name` column, and the `artists` table `Name` column where the `artists` table `ArtistId` is equal to the `albums` table `ArtistId`.

# %% [markdown]
# ### Exercise 3

# %%
# %%sql
#
# SELECT
#     t.TrackId,
#     ii.InvoiceId
# FROM
#     tracks t
# LEFT JOIN
#     invoice_items ii
#     ON t.TrackId = ii.TrackId
# LIMIT 10;  -- Remove this line to see the full query output

# %% [markdown]
# ### Exercise 4

# %%
# %%sql
#
# SELECT
#     t.TrackId,
#     ii.InvoiceId
# FROM
#     tracks AS t
# LEFT JOIN
#     invoice_items AS ii
#     ON t.TrackId = ii.TrackId
# WHERE ii.InvoiceId IS NULL
# LIMIT 10;  -- Remove this line to see the full query output

# %% [markdown]
# ### Exercise 5

# %%
# %%sql
#
# SELECT
#     g.Name AS "Genre",
#     m.Name AS "Media Type"
# FROM
#     genres AS g
# CROSS JOIN
#     media_types AS m
# LIMIT 10;  -- Remove this line to see the full query output

# %% [markdown]
# #
#
# <div align="center" style=" font-size: 80%; text-align: center; margin: 0 auto">
# <img src="https://raw.githubusercontent.com/Explore-AI/Pictures/refs/heads/master/ALX_banners/ALX_Navy.png"  style="width:100px"  ;/>
# </div>
